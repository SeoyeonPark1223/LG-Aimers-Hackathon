# %% [markdown]
# # XGBoost - 베이스라인 버전 (one-hot encoding)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/sample_submission.csv
# /kaggle/input/train.csv
# /kaggle/input/test.csv

# %%
data_path = '/kaggle/input/'

train = pd.read_csv(data_path + 'train.csv', index_col= 'ID')
test = pd.read_csv(data_path + 'test.csv', index_col= 'ID')
submission = pd.read_csv(data_path + 'sample_submission.csv', index_col= 'ID')

# %% [markdown]
# ## 1. 데이터 통합

# %%
all_data = pd.concat([train, test], ignore_index= True)
all_data = all_data.drop('임신 성공 여부', axis= 1)

# %%
categorical_columns = [
    "시술 시기 코드",
    "시술 당시 나이",
    "시술 유형",
    "특정 시술 유형",
    "배란 자극 여부",
    "배란 유도 유형",
    "단일 배아 이식 여부",
    "착상 전 유전 검사 사용 여부",
    "착상 전 유전 진단 사용 여부",
    "남성 주 불임 원인",
    "남성 부 불임 원인",
    "여성 주 불임 원인",
    "여성 부 불임 원인",
    "부부 주 불임 원인",
    "부부 부 불임 원인",
    "불명확 불임 원인",
    "불임 원인 - 난관 질환",
    "불임 원인 - 남성 요인",
    "불임 원인 - 배란 장애",
    "불임 원인 - 여성 요인",
    "불임 원인 - 자궁경부 문제",
    "불임 원인 - 자궁내막증",
    "불임 원인 - 정자 농도",
    "불임 원인 - 정자 면역학적 요인",
    "불임 원인 - 정자 운동성",
    "불임 원인 - 정자 형태",
    "배아 생성 주요 이유",
    "총 시술 횟수",
    "클리닉 내 총 시술 횟수",
    "IVF 시술 횟수",
    "DI 시술 횟수",
    "총 임신 횟수",
    "IVF 임신 횟수",
    "DI 임신 횟수",
    "총 출산 횟수",
    "IVF 출산 횟수",
    "DI 출산 횟수",
    "난자 출처",
    "정자 출처",
    "난자 기증자 나이",
    "정자 기증자 나이",
    "동결 배아 사용 여부",
    "신선 배아 사용 여부",
    "기증 배아 사용 여부",
    "대리모 여부",
    "PGD 시술 여부",
    "PGS 시술 여부"
]

# %%
# 카테고리형 컬럼들을 문자열로 변환
for col in categorical_columns:
    all_data[col] = all_data[col].astype(str)

# %% [markdown]
# ## 2. 피처 엔지니어링: 원 핫 인코딩

# %%
from sklearn.preprocessing import OneHotEncoder

onehot_encoder = OneHotEncoder()

encoded_cat_matrix = onehot_encoder.fit_transform(all_data[categorical_columns])

encoded_cat_matrix
# Out:
# <346418x205 sparse matrix of type '<class 'numpy.float64'>'
# 	with 16281646 stored elements in Compressed Sparse Row format>

# %%
numeric_columns = [
    "임신 시도 또는 마지막 임신 경과 연수",
    "총 생성 배아 수",
    "미세주입된 난자 수",
    "미세주입에서 생성된 배아 수",
    "이식된 배아 수",
    "미세주입 배아 이식 수",
    "저장된 배아 수",
    "미세주입 후 저장된 배아 수",
    "해동된 배아 수",
    "해동 난자 수",
    "수집된 신선 난자 수",
    "저장된 신선 난자 수",
    "혼합된 난자 수",
    "파트너 정자와 혼합된 난자 수",
    "기증자 정자와 혼합된 난자 수",
    "난자 채취 경과일",
    "난자 해동 경과일",
    "난자 혼합 경과일",
    "배아 이식 경과일",
    "배아 해동 경과일"
]

# %%
all_columns = all_data.columns
all_columns
# Out:
# Index(['시술 시기 코드', '시술 당시 나이', '임신 시도 또는 마지막 임신 경과 연수', '시술 유형', '특정 시술 유형',
#        '배란 자극 여부', '배란 유도 유형', '단일 배아 이식 여부', '착상 전 유전 검사 사용 여부',
#        '착상 전 유전 진단 사용 여부', '남성 주 불임 원인', '남성 부 불임 원인', '여성 주 불임 원인',
#        '여성 부 불임 원인', '부부 주 불임 원인', '부부 부 불임 원인', '불명확 불임 원인', '불임 원인 - 난관 질환',
#        '불임 원인 - 남성 요인', '불임 원인 - 배란 장애', '불임 원인 - 여성 요인', '불임 원인 - 자궁경부 문제',
#        '불임 원인 - 자궁내막증', '불임 원인 - 정자 농도', '불임 원인 - 정자 면역학적 요인',
#        '불임 원인 - 정자 운동성', '불임 원인 - 정자 형태', '배아 생성 주요 이유', '총 시술 횟수',
#        '클리닉 내 총 시술 횟수', 'IVF 시술 횟수', 'DI 시술 횟수', '총 임신 횟수', 'IVF 임신 횟수',
#        'DI 임신 횟수', '총 출산 횟수', 'IVF 출산 횟수', 'DI 출산 횟수', '총 생성 배아 수',
#        '미세주입된 난자 수', '미세주입에서 생성된 배아 수', '이식된 배아 수', '미세주입 배아 이식 수', '저장된 배아 수',
#        '미세주입 후 저장된 배아 수', '해동된 배아 수', '해동 난자 수', '수집된 신선 난자 수', '저장된 신선 난자 수',
#        '혼합된 난자 수', '파트너 정자와 혼합된 난자 수', '기증자 정자와 혼합된 난자 수', '난자 출처', '정자 출처',
#        '난자 기증자 나이', '정자 기증자 나이', '동결 배아 사용 여부', '신선 배아 사용 여부', '기증 배아 사용 여부',
#        '대리모 여부', 'PGD 시술 여부', 'PGS 시술 여부', '난자 채취 경과일', '난자 해동 경과일',
#        '난자 혼합 경과일', '배아 이식 경과일', '배아 해동 경과일'],
#       dtype='object')

# %%
len(all_columns)
# Out:
# 67

# %%
from scipy import sparse

extracted_data_sprs = sparse.hstack([sparse.csr_matrix(all_data[numeric_columns]),
                               encoded_cat_matrix],
                              format='csr')

# %% [markdown]
# ## 3. 데이터 나누기

# %%
num_train = len(train) 

X = extracted_data_sprs[:num_train]
X_test = extracted_data_sprs[num_train:]

y = train['임신 성공 여부'].values

# %% [markdown]
# ## 4. 파라미터 최적화

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split

# 8:2 비율로 훈련 데이터, 검증 데이터 분리 (베이지안 최적화 수행용)
X_train, X_valid, y_train, y_valid = train_test_split(X, y, 
                                                      test_size=0.2, 
                                                      random_state=0)
# 베이지안 최적화용 데이터셋
bayes_dtrain = xgb.DMatrix(X_train, y_train)
bayes_dvalid = xgb.DMatrix(X_valid, y_valid)

# %%
# 베이지안 최적화를 위한 하이퍼파라미터 범위
# TODO: 점점 좁혀나가자!!
param_bounds = {
    'max_depth': (6, 8),
    'subsample': (0.65, 0.9),
    'colsample_bytree': (0.8, 1.0),
    'min_child_weight': (6, 7),
    'gamma': (8, 10),
    'reg_alpha': (7, 9),
    'reg_lambda': (1.1, 1.5),
    'scale_pos_weight': (1.4, 1.6)
}

# 값이 고정된 하이퍼파라미터
fixed_params = {'objective': 'binary:logistic',
                'learning_rate': 0.02,
                'random_state': 1991}

# %%
from sklearn.metrics import roc_auc_score

# XGBoost 커스텀 평가 함수
def xgb_roc_auc(y_pred, dtrain):
    y_true = dtrain.get_label()
    return "roc_auc", roc_auc_score(y_true, y_pred)

# %%
from sklearn.metrics import roc_auc_score
from lightgbm import early_stopping

def eval_function(max_depth, subsample, colsample_bytree, min_child_weight,
                 reg_alpha, gamma, reg_lambda, scale_pos_weight):
    '''최적화하려는 평가지표(roc_auc) 계산 함수'''
    # 베이지안 최적화를 수행할 하이퍼파라미터
    params = {'max_depth': int(round(max_depth)),
              'subsample': subsample,
              'colsample_bytree': colsample_bytree,
              'min_child_weight': min_child_weight,
              'gamma': gamma,
              'reg_alpha':reg_alpha,
              'reg_lambda': reg_lambda,
              'scale_pos_weight': scale_pos_weight}
    # 값이 고정된 하이퍼파라미터도 추가
    params.update(fixed_params)
    
    print('하이퍼파라미터 :', params)    
        
    # XGBoost 모델 훈련
    xgb_model = xgb.train(params=params, 
                          dtrain=bayes_dtrain,
                          num_boost_round=2000,
                          evals=[(bayes_dvalid, 'bayes_dvalid')],
                          maximize=True,
                          custom_metric=xgb_roc_auc, 
                          callbacks=[xgb.callback.EarlyStopping(rounds=200)],
                          verbose_eval=0)
                           
    best_iter = xgb_model.best_iteration # 최적 반복 횟수
    # 검증 데이터로 예측 수행
    preds = xgb_model.predict(bayes_dvalid, 
                              iteration_range=(0, best_iter))
    # roc_auc 계산
    roc_auc = roc_auc_score(bayes_dvalid.get_label(), preds)
    print(f'roc_auc : {roc_auc}\n')
    
    return roc_auc

# %%
from bayes_opt import BayesianOptimization

# 베이지안 최적화 객체 생성
optimizer = BayesianOptimization(f=eval_function, 
                                 pbounds=param_bounds, 
                                 random_state=0)

# %%
# 베이지안 최적화 수행
# TODO: init_points 10~15, n_iter 30~70
optimizer.maximize(init_points=15, n_iter=60)
# Out:
# |   iter    |  target   | colsam... |   gamma   | max_depth | min_ch... | reg_alpha | reg_la... | scale_... | subsample |
# -------------------------------------------------------------------------------------------------------------------------
# 하이퍼파라미터 : {'max_depth': 7, 'subsample': 0.87294325019552, 'colsample_bytree': 0.909762700785465, 'min_child_weight': 6.544883182996897, 'gamma': 9.430378732744838, 'reg_alpha': 7.84730959867781, 'reg_lambda': 1.3583576452266626, 'scale_pos_weight': 1.4875174422525386, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7394381654769072
#
# | 1         | 0.7394    | 0.9098    | 9.43      | 7.206     | 6.545     | 7.847     | 1.358     | 1.488     | 0.8729    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.6717823249253851, 'colsample_bytree': 0.9927325521002058, 'min_child_weight': 6.528894919752904, 'gamma': 8.766883037651555, 'reg_alpha': 8.136089122187865, 'reg_lambda': 1.4702386553170643, 'scale_pos_weight': 1.4142072116395774, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7395156468160273
#
# | 2         | 0.7395    | 0.9927    | 8.767     | 7.583     | 6.529     | 8.136     | 1.47      | 1.414     | 0.6718    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8451322940716139, 'colsample_bytree': 0.8040436794880652, 'min_child_weight': 6.870012148246819, 'gamma': 9.665239691095875, 'reg_alpha': 8.957236684465528, 'reg_lambda': 1.4196634256866894, 'scale_pos_weight': 1.4922958724505864, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7395632801056773
#
# | 3         | 0.7396    | 0.804     | 9.665     | 7.556     | 6.87      | 8.957     | 1.42      | 1.492     | 0.8451    |
# 하이퍼파라미터 : {'max_depth': 6, 'subsample': 0.8435584223585542, 'colsample_bytree': 0.8236548851737867, 'min_child_weight': 6.944668917049584, 'gamma': 9.279842042655048, 'reg_alpha': 8.043696643500143, 'reg_lambda': 1.2658647759962094, 'scale_pos_weight': 1.4529111224209252, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7388395214195909
#
# | 4         | 0.7388    | 0.8237    | 9.28      | 6.287     | 6.945     | 8.044     | 1.266     | 1.453     | 0.8436    |
# 하이퍼파라미터 : {'max_depth': 6, 'subsample': 0.8204550747758709, 'colsample_bytree': 0.8912300664433097, 'min_child_weight': 6.617635497075877, 'gamma': 9.136867897737297, 'reg_alpha': 8.224191445444843, 'reg_lambda': 1.3467735987499028, 'scale_pos_weight': 1.5887496157029248, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7387868280677131
#
# | 5         | 0.7388    | 0.8912    | 9.137     | 6.038     | 6.618     | 8.224     | 1.347     | 1.589     | 0.8205    |
# 하이퍼파라미터 : {'max_depth': 7, 'subsample': 0.6822315744137133, 'colsample_bytree': 0.8719015801147573, 'min_child_weight': 6.06022547162927, 'gamma': 8.874063907598682, 'reg_alpha': 8.333533430891336, 'reg_lambda': 1.3682551478472638, 'scale_pos_weight': 1.442076512214768, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7393974875517632
#
# | 6         | 0.7394    | 0.8719    | 8.874     | 7.395     | 6.06      | 8.334     | 1.368     | 1.442     | 0.6822    |
# 하이퍼파라미터 : {'max_depth': 7, 'subsample': 0.6903273794712491, 'colsample_bytree': 0.8630856701848368, 'min_child_weight': 6.43860151346232, 'gamma': 8.727421541885246, 'reg_alpha': 8.976747676118453, 'reg_lambda': 1.1408179242992114, 'scale_pos_weight': 1.4417753512189668, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7393273613674732
#
# | 7         | 0.7393    | 0.8631    | 8.727     | 7.14      | 6.439     | 8.977     | 1.141     | 1.442     | 0.6903    |
# 하이퍼파라미터 : {'max_depth': 7, 'subsample': 0.6845457378371534, 'colsample_bytree': 0.9306216650930796, 'min_child_weight': 6.244425592001603, 'gamma': 8.506583205079565, 'reg_alpha': 7.31793916729104, 'reg_lambda': 1.144150056465722, 'scale_pos_weight': 1.5312659178930548, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7394974953481681
#
# | 8         | 0.7395    | 0.9306    | 8.507     | 6.933     | 6.244     | 7.318     | 1.144     | 1.531     | 0.6845    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.7671628004119254, 'colsample_bytree': 0.8393164723360107, 'min_child_weight': 6.097101275793062, 'gamma': 8.737450341321928, 'reg_alpha': 8.675889814997607, 'reg_lambda': 1.1384393631575853, 'scale_pos_weight': 1.5952918930026792, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7399555138992683
#
# | 9         | 0.74      | 0.8393    | 8.737     | 7.642     | 6.097     | 8.676     | 1.138     | 1.595     | 0.7672    |
# 하이퍼파라미터 : {'max_depth': 7, 'subsample': 0.679681929738561, 'colsample_bytree': 0.9953522176380674, 'min_child_weight': 6.039187792254321, 'gamma': 9.209691039490092, 'reg_alpha': 7.565613925152819, 'reg_lambda': 1.1480786244852677, 'scale_pos_weight': 1.459228039504429, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7392174150797475
#
# | 10        | 0.7392    | 0.9954    | 9.21      | 7.479     | 6.039     | 7.566     | 1.148     | 1.459     | 0.6797    |
# 하이퍼파라미터 : {'max_depth': 6, 'subsample': 0.6734851276896104, 'colsample_bytree': 0.8635966358787952, 'min_child_weight': 6.69247211937002, 'gamma': 8.82852598902934, 'reg_alpha': 8.13320290841315, 'reg_lambda': 1.2061557963757783, 'scale_pos_weight': 1.50464961069334, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7387671820750366
#
# | 11        | 0.7388    | 0.8636    | 8.829     | 6.128     | 6.692     | 8.133     | 1.206     | 1.505     | 0.6735    |
# 하이퍼파라미터 : {'max_depth': 7, 'subsample': 0.6957978405017793, 'colsample_bytree': 0.9151892991112359, 'min_child_weight': 6.667410379963682, 'gamma': 9.858592395152428, 'reg_alpha': 7.263595724808784, 'reg_lambda': 1.3865308816474262, 'scale_pos_weight': 1.45788121858944, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7392647423570504
#
# | 12        | 0.7393    | 0.9152    | 9.859     | 6.637     | 6.667     | 7.264     | 1.387     | 1.458     | 0.6958    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8905471362793596, 'colsample_bytree': 0.9173025869620166, 'min_child_weight': 6.004695476192547, 'gamma': 8.040215092374988, 'reg_alpha': 8.355633073592461, 'reg_lambda': 1.208003189276866, 'scale_pos_weight': 1.5470388044245191, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7398957230352137
#
# | 13        | 0.7399    | 0.9173    | 8.04      | 7.658     | 6.005     | 8.356     | 1.208     | 1.547     | 0.8905    |
# 하이퍼파라미터 : {'max_depth': 7, 'subsample': 0.861602168117782, 'colsample_bytree': 0.8497506287039917, 'min_child_weight': 6.572251905790873, 'gamma': 9.152314668835674, 'reg_alpha': 7.446163265281236, 'reg_lambda': 1.481099604606794, 'scale_pos_weight': 1.4894250757235254, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7394805432512817
#
# | 14        | 0.7395    | 0.8498    | 9.152     | 7.184     | 6.572     | 7.446     | 1.481     | 1.489     | 0.8616    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8231328975194415, 'colsample_bytree': 0.9398958550635008, 'min_child_weight': 6.396505740846985, 'gamma': 8.594873901710267, 'reg_alpha': 8.762206394222323, 'reg_lambda': 1.3325091490543435, 'scale_pos_weight': 1.5763470723709707, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7395918093406458
#
# | 15        | 0.7396    | 0.9399    | 8.595     | 7.628     | 6.397     | 8.762     | 1.333     | 1.576     | 0.8231    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.833908349123449, 'colsample_bytree': 0.814407389252615, 'min_child_weight': 6.059178810127847, 'gamma': 8.4305843050889, 'reg_alpha': 8.605194670426076, 'reg_lambda': 1.1847213888803252, 'scale_pos_weight': 1.5705905290157376, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7398747404595765
#
# | 16        | 0.7399    | 0.8144    | 8.431     | 7.959     | 6.059     | 8.605     | 1.185     | 1.571     | 0.8339    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8918003598046779, 'colsample_bytree': 0.810494157499944, 'min_child_weight': 6.261842450335639, 'gamma': 8.029159029915084, 'reg_alpha': 7.680722056883285, 'reg_lambda': 1.1717341315250618, 'scale_pos_weight': 1.5778341184479794, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7400266272201615
#
# | 17        | 0.74      | 0.8105    | 8.029     | 7.845     | 6.262     | 7.681     | 1.172     | 1.578     | 0.8918    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8295719344573858, 'colsample_bytree': 0.8071210265163415, 'min_child_weight': 6.99040628945352, 'gamma': 8.070392830243678, 'reg_alpha': 7.098779136546568, 'reg_lambda': 1.4862616598403204, 'scale_pos_weight': 1.573932925708207, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7400274228522637
#
# | 18        | 0.74      | 0.8071    | 8.07      | 7.959     | 6.99      | 7.099     | 1.486     | 1.574     | 0.8296    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.6852431922572302, 'colsample_bytree': 0.8067411468557512, 'min_child_weight': 6.2820090392832935, 'gamma': 8.005922878483677, 'reg_alpha': 7.055644614674881, 'reg_lambda': 1.373202077032618, 'scale_pos_weight': 1.4261662324156152, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7397390930832504
#
# | 19        | 0.7397    | 0.8067    | 8.006     | 7.917     | 6.282     | 7.056     | 1.373     | 1.426     | 0.6852    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.808213932225148, 'colsample_bytree': 0.8969662241304518, 'min_child_weight': 6.99069639944612, 'gamma': 8.06371788561364, 'reg_alpha': 7.529428160207737, 'reg_lambda': 1.1073277328646225, 'scale_pos_weight': 1.5248802564853947, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7399238939395952
#
# | 20        | 0.7399    | 0.897     | 8.064     | 7.757     | 6.991     | 7.529     | 1.107     | 1.525     | 0.8082    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8824576031442923, 'colsample_bytree': 0.8619942861732676, 'min_child_weight': 6.032209189573005, 'gamma': 9.71963805166992, 'reg_alpha': 8.68171501103698, 'reg_lambda': 1.2142547573179538, 'scale_pos_weight': 1.569211126214838, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7397569819727732
#
# | 21        | 0.7398    | 0.862     | 9.72      | 7.993     | 6.032     | 8.682     | 1.214     | 1.569     | 0.8825    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.7556514217721764, 'colsample_bytree': 0.8116846772452847, 'min_child_weight': 6.999121078427891, 'gamma': 8.644235025209968, 'reg_alpha': 7.167210036437028, 'reg_lambda': 1.3160629657331797, 'scale_pos_weight': 1.5626346485579803, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7400102723409199
#
# | 22        | 0.74      | 0.8117    | 8.644     | 7.96      | 6.999     | 7.167     | 1.316     | 1.563     | 0.7557    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8871207090438747, 'colsample_bytree': 0.8411915242842714, 'min_child_weight': 6.974103549884315, 'gamma': 9.987697431362983, 'reg_alpha': 7.411172076230133, 'reg_lambda': 1.3336113885428822, 'scale_pos_weight': 1.472644089749492, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7396670469182671
#
# | 23        | 0.7397    | 0.8412    | 9.988     | 7.978     | 6.974     | 7.411     | 1.334     | 1.473     | 0.8871    |
# 하이퍼파라미터 : {'max_depth': 7, 'subsample': 0.8385259195751007, 'colsample_bytree': 0.9109750878733168, 'min_child_weight': 6.982592310698709, 'gamma': 8.032171567647477, 'reg_alpha': 7.00612589397429, 'reg_lambda': 1.30089238667652, 'scale_pos_weight': 1.5818599569736005, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7395255843202115
#
# | 24        | 0.7395    | 0.911     | 8.032     | 6.808     | 6.983     | 7.006     | 1.301     | 1.582     | 0.8385    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.7311640468200948, 'colsample_bytree': 0.8712972766364777, 'min_child_weight': 6.994717080354424, 'gamma': 9.3869595029531, 'reg_alpha': 8.171877379933076, 'reg_lambda': 1.1058456973689346, 'scale_pos_weight': 1.587520559088608, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7397411384302921
#
# | 25        | 0.7397    | 0.8713    | 9.387     | 7.956     | 6.995     | 8.172     | 1.106     | 1.588     | 0.7312    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8144380511131764, 'colsample_bytree': 0.968476884842064, 'min_child_weight': 6.867269454468948, 'gamma': 8.509207853527208, 'reg_alpha': 7.523850169459483, 'reg_lambda': 1.4833813582872768, 'scale_pos_weight': 1.591123540286501, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7397102815272133
#
# | 26        | 0.7397    | 0.9685    | 8.509     | 7.969     | 6.867     | 7.524     | 1.483     | 1.591     | 0.8144    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.6703484033794146, 'colsample_bytree': 0.9414139929770488, 'min_child_weight': 6.032257774841379, 'gamma': 8.80114408080387, 'reg_alpha': 8.947146167283114, 'reg_lambda': 1.1425070150421002, 'scale_pos_weight': 1.534662926893322, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7396317024921901
#
# | 27        | 0.7396    | 0.9414    | 8.801     | 7.904     | 6.032     | 8.947     | 1.143     | 1.535     | 0.6703    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.6745180783721842, 'colsample_bytree': 0.8698387602826592, 'min_child_weight': 6.742640716402238, 'gamma': 8.106248572761814, 'reg_alpha': 7.0099280807617355, 'reg_lambda': 1.1011507927031443, 'scale_pos_weight': 1.5156839256992372, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7398904556742991
#
# | 28        | 0.7399    | 0.8698    | 8.106     | 7.886     | 6.743     | 7.01      | 1.101     | 1.516     | 0.6745    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.6757442218430265, 'colsample_bytree': 0.8013078139172813, 'min_child_weight': 6.471505665064565, 'gamma': 8.272904409274837, 'reg_alpha': 8.01120803823721, 'reg_lambda': 1.1076766099406121, 'scale_pos_weight': 1.5583075729974634, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7397657684756781
#
# | 29        | 0.7398    | 0.8013    | 8.273     | 7.828     | 6.472     | 8.011     | 1.108     | 1.558     | 0.6757    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8916472675475634, 'colsample_bytree': 0.9691193132449969, 'min_child_weight': 6.981341479017284, 'gamma': 9.060018818106059, 'reg_alpha': 7.026460784814357, 'reg_lambda': 1.1950140283140607, 'scale_pos_weight': 1.595520067442226, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7396833830419132
#
# | 30        | 0.7397    | 0.9691    | 9.06      | 7.581     | 6.981     | 7.026     | 1.195     | 1.596     | 0.8916    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8633843318951578, 'colsample_bytree': 0.8169641755608767, 'min_child_weight': 6.934253372814407, 'gamma': 8.221913962878938, 'reg_alpha': 7.173791672446782, 'reg_lambda': 1.475347897690175, 'scale_pos_weight': 1.435805011981335, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7399127669358042
#
# | 31        | 0.7399    | 0.817     | 8.222     | 7.558     | 6.934     | 7.174     | 1.475     | 1.436     | 0.8634    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.872834514213775, 'colsample_bytree': 0.8216738013415409, 'min_child_weight': 6.031410166581132, 'gamma': 8.19078747717902, 'reg_alpha': 7.719777638446697, 'reg_lambda': 1.1022537064978413, 'scale_pos_weight': 1.5687627083793383, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7400196837012947
#
# | 32        | 0.74      | 0.8217    | 8.191     | 7.596     | 6.031     | 7.72      | 1.102     | 1.569     | 0.8728    |
# 하이퍼파라미터 : {'max_depth': 7, 'subsample': 0.8803534586741661, 'colsample_bytree': 0.9669914821815421, 'min_child_weight': 6.025623078652847, 'gamma': 8.00298551289959, 'reg_alpha': 7.791853266148698, 'reg_lambda': 1.1297618848228759, 'scale_pos_weight': 1.5750232017048256, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7395623235703087
#
# | 33        | 0.7396    | 0.967     | 8.003     | 7.279     | 6.026     | 7.792     | 1.13      | 1.575     | 0.8804    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8763117299342179, 'colsample_bytree': 0.8232206025999336, 'min_child_weight': 6.042867784546467, 'gamma': 8.19883846601378, 'reg_alpha': 7.941822463792214, 'reg_lambda': 1.3170213350192468, 'scale_pos_weight': 1.5400617054159031, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7399733731746931
#
# | 34        | 0.74      | 0.8232    | 8.199     | 7.965     | 6.043     | 7.942     | 1.317     | 1.54      | 0.8763    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8957354500341429, 'colsample_bytree': 0.8075990467572284, 'min_child_weight': 6.0428761460554155, 'gamma': 8.56348714885065, 'reg_alpha': 7.2411463003631, 'reg_lambda': 1.3903229335164795, 'scale_pos_weight': 1.5769851585689372, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7400414856003126
#
# | 35        | 0.74      | 0.8076    | 8.563     | 7.979     | 6.043     | 7.241     | 1.39      | 1.577     | 0.8957    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8234283094259349, 'colsample_bytree': 0.9541904030712192, 'min_child_weight': 6.0486970031391, 'gamma': 8.538107323849609, 'reg_alpha': 7.574062330428666, 'reg_lambda': 1.1095643596697584, 'scale_pos_weight': 1.5715519977759076, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7397023745630218
#
# | 36        | 0.7397    | 0.9542    | 8.538     | 7.931     | 6.049     | 7.574     | 1.11      | 1.572     | 0.8234    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.872919052013001, 'colsample_bytree': 0.9841949001381829, 'min_child_weight': 6.985885452417479, 'gamma': 8.36643365274492, 'reg_alpha': 7.065420369558089, 'reg_lambda': 1.148986238355743, 'scale_pos_weight': 1.4312576529644012, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7397087021086481
#
# | 37        | 0.7397    | 0.9842    | 8.366     | 7.949     | 6.986     | 7.065     | 1.149     | 1.431     | 0.8729    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8470364979210778, 'colsample_bytree': 0.8381480737797897, 'min_child_weight': 6.440321322645939, 'gamma': 8.655125353809566, 'reg_alpha': 7.053799495389526, 'reg_lambda': 1.379110718926251, 'scale_pos_weight': 1.5625226125735334, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7399304949220606
#
# | 38        | 0.7399    | 0.8381    | 8.655     | 7.902     | 6.44      | 7.054     | 1.379     | 1.563     | 0.847     |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8701833587761124, 'colsample_bytree': 0.8581929258608152, 'min_child_weight': 6.0359894762621344, 'gamma': 8.399475584293363, 'reg_alpha': 7.366258076679742, 'reg_lambda': 1.487320732945574, 'scale_pos_weight': 1.5714621583037456, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.740015471589409
#
# | 39        | 0.74      | 0.8582    | 8.399     | 7.66      | 6.036     | 7.366     | 1.487     | 1.571     | 0.8702    |
# 하이퍼파라미터 : {'max_depth': 6, 'subsample': 0.6889583839544657, 'colsample_bytree': 0.8197422630780488, 'min_child_weight': 6.058509181622397, 'gamma': 8.01407821839258, 'reg_alpha': 7.016280418887102, 'reg_lambda': 1.4706511907911375, 'scale_pos_weight': 1.5307548208445572, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.739084945296147
#
# | 40        | 0.7391    | 0.8197    | 8.014     | 6.037     | 6.059     | 7.016     | 1.471     | 1.531     | 0.689     |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.775781455016558, 'colsample_bytree': 0.8368823503715648, 'min_child_weight': 6.995758968672748, 'gamma': 8.948312626138318, 'reg_alpha': 7.019860566371673, 'reg_lambda': 1.4934161111979254, 'scale_pos_weight': 1.420396531540733, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7397282533362108
#
# | 41        | 0.7397    | 0.8369    | 8.948     | 7.988     | 6.996     | 7.02      | 1.493     | 1.42      | 0.7758    |
# 하이퍼파라미터 : {'max_depth': 7, 'subsample': 0.6839112891482462, 'colsample_bytree': 0.8592980580983708, 'min_child_weight': 6.01952152506616, 'gamma': 9.980151064794065, 'reg_alpha': 8.923006132729233, 'reg_lambda': 1.1139834661842916, 'scale_pos_weight': 1.4760837291618103, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7391666229529674
#
# | 42        | 0.7392    | 0.8593    | 9.98      | 7.302     | 6.02      | 8.923     | 1.114     | 1.476     | 0.6839    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.7615627587882514, 'colsample_bytree': 0.8817496109261715, 'min_child_weight': 6.879791956577714, 'gamma': 9.99943773783037, 'reg_alpha': 8.321407504366665, 'reg_lambda': 1.209646081539084, 'scale_pos_weight': 1.5083484445154012, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7395978673979796
#
# | 43        | 0.7396    | 0.8817    | 9.999     | 7.974     | 6.88      | 8.321     | 1.21      | 1.508     | 0.7616    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.6896392592249607, 'colsample_bytree': 0.8058647396753151, 'min_child_weight': 6.736139561737058, 'gamma': 8.353202268904395, 'reg_alpha': 7.123005036925116, 'reg_lambda': 1.2150893141494505, 'scale_pos_weight': 1.593007982827926, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7398834835284709
#
# | 44        | 0.7399    | 0.8059    | 8.353     | 7.513     | 6.736     | 7.123     | 1.215     | 1.593     | 0.6896    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.7333675513594405, 'colsample_bytree': 0.8632246677668995, 'min_child_weight': 6.104697112506812, 'gamma': 9.811787348775887, 'reg_alpha': 7.104610913714558, 'reg_lambda': 1.3363066389085385, 'scale_pos_weight': 1.5888290799767755, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7397836840178892
#
# | 45        | 0.7398    | 0.8632    | 9.812     | 7.987     | 6.105     | 7.105     | 1.336     | 1.589     | 0.7334    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8972554985760678, 'colsample_bytree': 0.9081750220352365, 'min_child_weight': 6.955304732834314, 'gamma': 8.020056837245392, 'reg_alpha': 8.983031831123236, 'reg_lambda': 1.1135230508968452, 'scale_pos_weight': 1.5790343142540524, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.739865773310673
#
# | 46        | 0.7399    | 0.9082    | 8.02      | 7.971     | 6.955     | 8.983     | 1.114     | 1.579     | 0.8973    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8851382032223492, 'colsample_bytree': 0.8390995195686693, 'min_child_weight': 6.946753073337397, 'gamma': 8.110641753581646, 'reg_alpha': 8.332697500159805, 'reg_lambda': 1.1016577562018066, 'scale_pos_weight': 1.4795777982214902, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.739829422005261
#
# | 47        | 0.7398    | 0.8391    | 8.111     | 7.862     | 6.947     | 8.333     | 1.102     | 1.48      | 0.8851    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8909409332241942, 'colsample_bytree': 0.8424635979841971, 'min_child_weight': 6.10606961324822, 'gamma': 8.425498527796305, 'reg_alpha': 7.06916003529429, 'reg_lambda': 1.2954744474302597, 'scale_pos_weight': 1.5320978496711524, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7398543333845787
#
# | 48        | 0.7399    | 0.8425    | 8.425     | 7.584     | 6.106     | 7.069     | 1.295     | 1.532     | 0.8909    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8301732322097155, 'colsample_bytree': 0.882219664464666, 'min_child_weight': 6.046460916054565, 'gamma': 9.947204173701428, 'reg_alpha': 7.8552785431840695, 'reg_lambda': 1.4919718263035788, 'scale_pos_weight': 1.4543863026986974, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7395960698222251
#
# | 49        | 0.7396    | 0.8822    | 9.947     | 7.873     | 6.046     | 7.855     | 1.492     | 1.454     | 0.8302    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.7303992736409448, 'colsample_bytree': 0.8015625975202815, 'min_child_weight': 6.027635016856203, 'gamma': 8.026986039303875, 'reg_alpha': 7.591934007645512, 'reg_lambda': 1.4277780118198269, 'scale_pos_weight': 1.5246809788615436, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7400542956720121
#
# | 50        | 0.7401    | 0.8016    | 8.027     | 7.787     | 6.028     | 7.592     | 1.428     | 1.525     | 0.7304    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8212108556418776, 'colsample_bytree': 0.8009778582971364, 'min_child_weight': 6.30643109513615, 'gamma': 8.032069148976554, 'reg_alpha': 7.774416286995126, 'reg_lambda': 1.497779289130357, 'scale_pos_weight': 1.4187718707763863, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.739997184883835
#
# | 51        | 0.74      | 0.801     | 8.032     | 7.709     | 6.306     | 7.774     | 1.498     | 1.419     | 0.8212    |
# 하이퍼파라미터 : {'max_depth': 7, 'subsample': 0.7928964996938364, 'colsample_bytree': 0.803752405425955, 'min_child_weight': 6.950716921331605, 'gamma': 8.133824374312805, 'reg_alpha': 7.717589487808898, 'reg_lambda': 1.3768686863320436, 'scale_pos_weight': 1.5564477773407377, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7396582653510452
#
# | 52        | 0.7397    | 0.8038    | 8.134     | 7.411     | 6.951     | 7.718     | 1.377     | 1.556     | 0.7929    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.7277837955295146, 'colsample_bytree': 0.8083855527310668, 'min_child_weight': 6.8718372041067575, 'gamma': 8.038669094318934, 'reg_alpha': 7.5127974956231025, 'reg_lambda': 1.4833773969649586, 'scale_pos_weight': 1.511996213613888, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7399801784944354
#
# | 53        | 0.74      | 0.8084    | 8.039     | 7.991     | 6.872     | 7.513     | 1.483     | 1.512     | 0.7278    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8982239956370648, 'colsample_bytree': 0.8220056326416723, 'min_child_weight': 6.20348390613531, 'gamma': 8.944676609084526, 'reg_alpha': 8.27307735545326, 'reg_lambda': 1.1249256801025087, 'scale_pos_weight': 1.4555891804904546, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.739822586084284
#
# | 54        | 0.7398    | 0.822     | 8.945     | 7.991     | 6.203     | 8.273     | 1.125     | 1.456     | 0.8982    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.707295057103474, 'colsample_bytree': 0.8057775122590116, 'min_child_weight': 6.2283716256202855, 'gamma': 8.310492696374682, 'reg_alpha': 7.498811942843763, 'reg_lambda': 1.478515695165107, 'scale_pos_weight': 1.5962020206533432, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7399470531514425
#
# | 55        | 0.7399    | 0.8058    | 8.31      | 7.701     | 6.228     | 7.499     | 1.479     | 1.596     | 0.7073    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8889591981631464, 'colsample_bytree': 0.8396797193346074, 'min_child_weight': 6.060090868965636, 'gamma': 8.254935533242456, 'reg_alpha': 7.419236593367673, 'reg_lambda': 1.3409158430482635, 'scale_pos_weight': 1.4873990862870756, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7398471026089606
#
# | 56        | 0.7398    | 0.8397    | 8.255     | 7.846     | 6.06      | 7.419     | 1.341     | 1.487     | 0.889     |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.6988640834435141, 'colsample_bytree': 0.8009313444565991, 'min_child_weight': 6.114522664126213, 'gamma': 9.16964890801957, 'reg_alpha': 7.130376527817526, 'reg_lambda': 1.4592492946315796, 'scale_pos_weight': 1.5818715540547827, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7397362994866633
#
# | 57        | 0.7397    | 0.8009    | 9.17      | 7.976     | 6.115     | 7.13      | 1.459     | 1.582     | 0.6989    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.6672419001113417, 'colsample_bytree': 0.8330068872451702, 'min_child_weight': 6.8689134866591735, 'gamma': 8.022243190777159, 'reg_alpha': 8.70934259019226, 'reg_lambda': 1.464085874855141, 'scale_pos_weight': 1.4662775467911087, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7398126219274115
#
# | 58        | 0.7398    | 0.833     | 8.022     | 8.0       | 6.869     | 8.709     | 1.464     | 1.466     | 0.6672    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.829082346655716, 'colsample_bytree': 0.8579012485956046, 'min_child_weight': 6.052158194884635, 'gamma': 8.140521667326905, 'reg_alpha': 7.8090876773030455, 'reg_lambda': 1.496550989779946, 'scale_pos_weight': 1.5678835382434952, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7398821992637501
#
# | 59        | 0.7399    | 0.8579    | 8.141     | 7.684     | 6.052     | 7.809     | 1.497     | 1.568     | 0.8291    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.7581112998359217, 'colsample_bytree': 0.8187080692622709, 'min_child_weight': 6.0062081481506695, 'gamma': 8.127586973887073, 'reg_alpha': 8.07955715765526, 'reg_lambda': 1.117361448503739, 'scale_pos_weight': 1.4297200481051477, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.739841242966084
#
# | 60        | 0.7398    | 0.8187    | 8.128     | 7.853     | 6.006     | 8.08      | 1.117     | 1.43      | 0.7581    |
# 하이퍼파라미터 : {'max_depth': 7, 'subsample': 0.7951197499190157, 'colsample_bytree': 0.8019383026463535, 'min_child_weight': 6.019458714211191, 'gamma': 8.082887023353198, 'reg_alpha': 8.8260398112339, 'reg_lambda': 1.1130846010515363, 'scale_pos_weight': 1.5657295913619556, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7396027655698046
#
# | 61        | 0.7396    | 0.8019    | 8.083     | 7.391     | 6.019     | 8.826     | 1.113     | 1.566     | 0.7951    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.6617026500547544, 'colsample_bytree': 0.8008244634511921, 'min_child_weight': 6.958935290806581, 'gamma': 8.17954938645675, 'reg_alpha': 7.162721461979509, 'reg_lambda': 1.4965666883482485, 'scale_pos_weight': 1.5920636031978517, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7399282866974795
#
# | 62        | 0.7399    | 0.8008    | 8.18      | 7.866     | 6.959     | 7.163     | 1.497     | 1.592     | 0.6617    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.7765871160978428, 'colsample_bytree': 0.8337878764634943, 'min_child_weight': 6.9869474993192755, 'gamma': 8.631436777076079, 'reg_alpha': 8.952175749647381, 'reg_lambda': 1.2700349517828349, 'scale_pos_weight': 1.5427133389984733, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7397487472792295
#
# | 63        | 0.7397    | 0.8338    | 8.631     | 7.995     | 6.987     | 8.952     | 1.27      | 1.543     | 0.7766    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8866759829152666, 'colsample_bytree': 0.8815612921210869, 'min_child_weight': 6.476041154453753, 'gamma': 8.038478982651007, 'reg_alpha': 8.349444865868737, 'reg_lambda': 1.4588095632859983, 'scale_pos_weight': 1.5571445199379765, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7399444362523074
#
# | 64        | 0.7399    | 0.8816    | 8.038     | 7.927     | 6.476     | 8.349     | 1.459     | 1.557     | 0.8867    |
# 하이퍼파라미터 : {'max_depth': 6, 'subsample': 0.7902159384362517, 'colsample_bytree': 0.9023829181099792, 'min_child_weight': 6.9666161496390355, 'gamma': 8.017596966971887, 'reg_alpha': 8.971237904582363, 'reg_lambda': 1.4374248725702143, 'scale_pos_weight': 1.4353294694122092, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7388904537197687
#
# | 65        | 0.7389    | 0.9024    | 8.018     | 6.071     | 6.967     | 8.971     | 1.437     | 1.435     | 0.7902    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8844475500056169, 'colsample_bytree': 0.9996448611861369, 'min_child_weight': 6.711291538428347, 'gamma': 8.038372096054754, 'reg_alpha': 8.060087298212967, 'reg_lambda': 1.496954929690354, 'scale_pos_weight': 1.423185000826467, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7397157463154485
#
# | 66        | 0.7397    | 0.9996    | 8.038     | 7.945     | 6.711     | 8.06      | 1.497     | 1.423     | 0.8844    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.812031545303407, 'colsample_bytree': 0.8118979096878562, 'min_child_weight': 6.588452038399986, 'gamma': 8.024705468492462, 'reg_alpha': 7.27157627807763, 'reg_lambda': 1.4313431086793282, 'scale_pos_weight': 1.5781020784032305, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7400581385948084
#
# | 67        | 0.7401    | 0.8119    | 8.025     | 7.992     | 6.588     | 7.272     | 1.431     | 1.578     | 0.812     |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8417007007778384, 'colsample_bytree': 0.8017008238991832, 'min_child_weight': 6.283338093311873, 'gamma': 8.058828614190377, 'reg_alpha': 7.62432380916907, 'reg_lambda': 1.4924588761010948, 'scale_pos_weight': 1.5930838410683477, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7399926095056794
#
# | 68        | 0.74      | 0.8017    | 8.059     | 7.953     | 6.283     | 7.624     | 1.492     | 1.593     | 0.8417    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.879872640465336, 'colsample_bytree': 0.83100305182246, 'min_child_weight': 6.617094996274681, 'gamma': 8.0503356372611, 'reg_alpha': 7.3168709375076535, 'reg_lambda': 1.2463377314671225, 'scale_pos_weight': 1.5214260635820143, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7400670257856468
#
# | 69        | 0.7401    | 0.831     | 8.05      | 7.714     | 6.617     | 7.317     | 1.246     | 1.521     | 0.8799    |
# 하이퍼파라미터 : {'max_depth': 7, 'subsample': 0.8063014498863571, 'colsample_bytree': 0.8158182719885486, 'min_child_weight': 6.118408347825716, 'gamma': 8.030921390215937, 'reg_alpha': 7.329631540407596, 'reg_lambda': 1.3144184294938737, 'scale_pos_weight': 1.5867875281734236, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7397668345832096
#
# | 70        | 0.7398    | 0.8158    | 8.031     | 7.436     | 6.118     | 7.33      | 1.314     | 1.587     | 0.8063    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.663926909071429, 'colsample_bytree': 0.8089829470266824, 'min_child_weight': 6.971409458751436, 'gamma': 9.074166462546573, 'reg_alpha': 7.558178920894029, 'reg_lambda': 1.1015057949266107, 'scale_pos_weight': 1.4613001799693848, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7395202241684564
#
# | 71        | 0.7395    | 0.809     | 9.074     | 7.881     | 6.971     | 7.558     | 1.102     | 1.461     | 0.6639    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.6660028811515076, 'colsample_bytree': 0.8111728186077982, 'min_child_weight': 6.981957091689793, 'gamma': 8.121199587406768, 'reg_alpha': 7.277894618971642, 'reg_lambda': 1.125466329658145, 'scale_pos_weight': 1.5906827746530274, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7399286312081539
#
# | 72        | 0.7399    | 0.8112    | 8.121     | 7.931     | 6.982     | 7.278     | 1.125     | 1.591     | 0.666     |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8831271650353826, 'colsample_bytree': 0.8622902684968804, 'min_child_weight': 6.676702575843448, 'gamma': 9.20486183291389, 'reg_alpha': 8.666801805314782, 'reg_lambda': 1.1102037860778111, 'scale_pos_weight': 1.4053798255387482, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7397116418014524
#
# | 73        | 0.7397    | 0.8623    | 9.205     | 7.934     | 6.677     | 8.667     | 1.11      | 1.405     | 0.8831    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8882167666955701, 'colsample_bytree': 0.8279582426936158, 'min_child_weight': 6.433416792320325, 'gamma': 8.038647619441194, 'reg_alpha': 8.417220327679916, 'reg_lambda': 1.1151348681383326, 'scale_pos_weight': 1.4243188513970935, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7398213264979784
#
# | 74        | 0.7398    | 0.828     | 8.039     | 7.982     | 6.433     | 8.417     | 1.115     | 1.424     | 0.8882    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.65, 'colsample_bytree': 0.8, 'min_child_weight': 6.0, 'gamma': 9.122023563086993, 'reg_alpha': 8.499715711407998, 'reg_lambda': 1.1, 'scale_pos_weight': 1.6, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7395224027789395
#
# | 75        | 0.7395    | 0.8       | 9.122     | 8.0       | 6.0       | 8.5       | 1.1       | 1.6       | 0.65      |
# =========================================================================================================================

# %%
# 평가함수 점수가 최대일 때 하이퍼파라미터
max_params = optimizer.max['params']
max_params
# Out:
# {'colsample_bytree': 0.83100305182246,
#  'gamma': 8.0503356372611,
#  'max_depth': 7.714205395057098,
#  'min_child_weight': 6.617094996274681,
#  'reg_alpha': 7.3168709375076535,
#  'reg_lambda': 1.2463377314671225,
#  'scale_pos_weight': 1.5214260635820143,
#  'subsample': 0.879872640465336}

# %%
# 정수형 하이퍼파라미터 변환
max_params['max_depth'] = int(round(max_params['max_depth']))

# 값이 고정된 하이퍼파라미터 추가
max_params.update(fixed_params)

# %%
max_params
# Out:
# {'colsample_bytree': 0.83100305182246,
#  'gamma': 8.0503356372611,
#  'max_depth': 8,
#  'min_child_weight': 6.617094996274681,
#  'reg_alpha': 7.3168709375076535,
#  'reg_lambda': 1.2463377314671225,
#  'scale_pos_weight': 1.5214260635820143,
#  'subsample': 0.879872640465336,
#  'objective': 'binary:logistic',
#  'learning_rate': 0.02,
#  'random_state': 1991}

# %% [markdown]
# ## 5. 모델 훈련

# %%
from sklearn.model_selection import StratifiedKFold

# 층화 K 폴드 교차 검증기 생성
folds = StratifiedKFold(n_splits=10, shuffle=True, random_state=1991)

# OOF 방식으로 훈련된 모델로 검증 데이터 타깃값을 예측한 확률을 담을 1차원 배열
oof_val_preds = np.zeros(X.shape[0]) 
# OOF 방식으로 훈련된 모델로 테스트 데이터 타깃값을 예측한 확률을 담을 1차원 배열
oof_test_preds = np.zeros(X_test.shape[0]) 

# OOF 방식으로 모델 훈련, 검증, 예측
for idx, (train_idx, valid_idx) in enumerate(folds.split(X, y)):
    # 각 폴드를 구분하는 문구 출력
    print('#'*40, f'폴드 {idx+1} / 폴드 {folds.n_splits}', '#'*40)
    
    # 훈련용 데이터, 검증용 데이터 설정
    X_train, y_train = X[train_idx], y[train_idx]
    X_valid, y_valid = X[valid_idx], y[valid_idx]

    # XGBoost 전용 데이터셋 생성 
    dtrain = xgb.DMatrix(X_train, y_train)
    dvalid = xgb.DMatrix(X_valid, y_valid)
    dtest = xgb.DMatrix(X_test)
    # XGBoost 모델 훈련
    xgb_model = xgb.train(params=max_params, 
                          dtrain=dtrain,
                          num_boost_round=2000,
                          evals=[(dvalid, 'valid')],
                          maximize=True,
                          custom_metric=xgb_roc_auc, 
                          callbacks=[xgb.callback.EarlyStopping(rounds=200)],
                          verbose_eval=0)

    # 모델 성능이 가장 좋을 때의 부스팅 반복 횟수 저장
    best_iter = xgb_model.best_iteration
    # 테스트 데이터를 활용해 OOF 예측
    oof_test_preds += xgb_model.predict(dtest,
                                        iteration_range=(0, best_iter))/folds.n_splits
    
    # 모델 성능 평가를 위한 검증 데이터 타깃값 예측 
    oof_val_preds[valid_idx] += xgb_model.predict(dvalid, 
                                                  iteration_range=(0, best_iter))
    
    # 검증 데이터 예측 확률에 대한 ROC-AUC
    roc_auc = roc_auc_score(dvalid.get_label(), oof_val_preds[valid_idx])
    print(f'폴드 {idx+1} roc-auc : {roc_auc}\n')

# %% [markdown]
# ## 6. 최종 결과

# %%
print('OOF 검증 데이터 roc-auc :', roc_auc_score(y, oof_val_preds))

# %%
submission['probability'] = oof_test_preds
submission.to_csv('xgb_onehot_submission.csv')
