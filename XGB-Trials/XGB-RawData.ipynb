# %% [markdown]
# # XGBoost - 전체 데이터셋

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/lg-aimers/sample_submission.csv
# /kaggle/input/lg-aimers/train.csv
# /kaggle/input/lg-aimers/test.csv

# %%
data_path = '/kaggle/input/lg-aimers/'

train = pd.read_csv(data_path + 'train.csv', index_col= 'ID')
test = pd.read_csv(data_path + 'test.csv', index_col= 'ID')
submission = pd.read_csv(data_path + 'sample_submission.csv', index_col= 'ID')

# %% [markdown]
# ## 1. 데이터 통합

# %%
all_data = pd.concat([train, test], ignore_index= True)
all_data = all_data.drop('임신 성공 여부', axis= 1)

# %%
categorical_columns = [
    "시술 시기 코드",
    "시술 당시 나이",
    "시술 유형",
    "특정 시술 유형",
    "배란 자극 여부",
    "배란 유도 유형",
    "단일 배아 이식 여부",
    "착상 전 유전 검사 사용 여부",
    "착상 전 유전 진단 사용 여부",
    "남성 주 불임 원인",
    "남성 부 불임 원인",
    "여성 주 불임 원인",
    "여성 부 불임 원인",
    "부부 주 불임 원인",
    "부부 부 불임 원인",
    "불명확 불임 원인",
    "불임 원인 - 난관 질환",
    "불임 원인 - 남성 요인",
    "불임 원인 - 배란 장애",
    "불임 원인 - 여성 요인",
    "불임 원인 - 자궁경부 문제",
    "불임 원인 - 자궁내막증",
    "불임 원인 - 정자 농도",
    "불임 원인 - 정자 면역학적 요인",
    "불임 원인 - 정자 운동성",
    "불임 원인 - 정자 형태",
    "배아 생성 주요 이유",
    "총 시술 횟수",
    "클리닉 내 총 시술 횟수",
    "IVF 시술 횟수",
    "DI 시술 횟수",
    "총 임신 횟수",
    "IVF 임신 횟수",
    "DI 임신 횟수",
    "총 출산 횟수",
    "IVF 출산 횟수",
    "DI 출산 횟수",
    "난자 출처",
    "정자 출처",
    "난자 기증자 나이",
    "정자 기증자 나이",
    "동결 배아 사용 여부",
    "신선 배아 사용 여부",
    "기증 배아 사용 여부",
    "대리모 여부",
    "PGD 시술 여부",
    "PGS 시술 여부"
]

# %%
# 카테고리형 컬럼들을 문자열로 변환
for col in categorical_columns:
    all_data[col] = all_data[col].astype(str)

# %% [markdown]
# ## 2. 피처 엔지니어링: 원 핫 인코딩

# %%
from sklearn.preprocessing import OneHotEncoder

onehot_encoder = OneHotEncoder()

encoded_cat_matrix = onehot_encoder.fit_transform(all_data[categorical_columns])

encoded_cat_matrix
# Out:
# <346418x205 sparse matrix of type '<class 'numpy.float64'>'
# 	with 16281646 stored elements in Compressed Sparse Row format>

# %%
all_columns = all_data.columns
all_columns
# Out:
# Index(['시술 시기 코드', '시술 당시 나이', '임신 시도 또는 마지막 임신 경과 연수', '시술 유형', '특정 시술 유형',
#        '배란 자극 여부', '배란 유도 유형', '단일 배아 이식 여부', '착상 전 유전 검사 사용 여부',
#        '착상 전 유전 진단 사용 여부', '남성 주 불임 원인', '남성 부 불임 원인', '여성 주 불임 원인',
#        '여성 부 불임 원인', '부부 주 불임 원인', '부부 부 불임 원인', '불명확 불임 원인', '불임 원인 - 난관 질환',
#        '불임 원인 - 남성 요인', '불임 원인 - 배란 장애', '불임 원인 - 여성 요인', '불임 원인 - 자궁경부 문제',
#        '불임 원인 - 자궁내막증', '불임 원인 - 정자 농도', '불임 원인 - 정자 면역학적 요인',
#        '불임 원인 - 정자 운동성', '불임 원인 - 정자 형태', '배아 생성 주요 이유', '총 시술 횟수',
#        '클리닉 내 총 시술 횟수', 'IVF 시술 횟수', 'DI 시술 횟수', '총 임신 횟수', 'IVF 임신 횟수',
#        'DI 임신 횟수', '총 출산 횟수', 'IVF 출산 횟수', 'DI 출산 횟수', '총 생성 배아 수',
#        '미세주입된 난자 수', '미세주입에서 생성된 배아 수', '이식된 배아 수', '미세주입 배아 이식 수', '저장된 배아 수',
#        '미세주입 후 저장된 배아 수', '해동된 배아 수', '해동 난자 수', '수집된 신선 난자 수', '저장된 신선 난자 수',
#        '혼합된 난자 수', '파트너 정자와 혼합된 난자 수', '기증자 정자와 혼합된 난자 수', '난자 출처', '정자 출처',
#        '난자 기증자 나이', '정자 기증자 나이', '동결 배아 사용 여부', '신선 배아 사용 여부', '기증 배아 사용 여부',
#        '대리모 여부', 'PGD 시술 여부', 'PGS 시술 여부', '난자 채취 경과일', '난자 해동 경과일',
#        '난자 혼합 경과일', '배아 이식 경과일', '배아 해동 경과일'],
#       dtype='object')

# %%
remaining_columns = list(set(all_columns) - set(categorical_columns))

# %%
from scipy import sparse

extracted_data_sprs = sparse.hstack([sparse.csr_matrix(all_data[remaining_columns]),
                               encoded_cat_matrix],
                              format='csr')

# %% [markdown]
# ## 3. 데이터 나누기

# %%
num_train = len(train) 

X = extracted_data_sprs[:num_train]
X_test = extracted_data_sprs[num_train:]

y = train['임신 성공 여부'].values

# %% [markdown]
# ## 4. 모델 훈련

# %% [markdown]
# ### 4-1. 베이지안 최적화

# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split

# 8:2 비율로 훈련 데이터, 검증 데이터 분리 (베이지안 최적화 수행용)
X_train, X_valid, y_train, y_valid = train_test_split(X, y, 
                                                      test_size=0.2, 
                                                      random_state=0)
# 베이지안 최적화용 데이터셋
bayes_dtrain = xgb.DMatrix(X_train, y_train)
bayes_dvalid = xgb.DMatrix(X_valid, y_valid)

# %%
# 베이지안 최적화를 위한 하이퍼파라미터 범위
# TODO: 점점 좁혀나가자!!
param_bounds = {
    'max_depth': (4, 8),
    'subsample': (0.6, 0.9),
    'colsample_bytree': (0.7, 1.0),
    'min_child_weight': (5, 7),
    'gamma': (8, 11),
    'reg_alpha': (7, 9),
    'reg_lambda': (1.1, 1.5),
    'scale_pos_weight': (1.4, 1.6)
}

# 값이 고정된 하이퍼파라미터
fixed_params = {'objective': 'binary:logistic',
                'learning_rate': 0.02,
                'random_state': 1991}

# %%
from sklearn.metrics import roc_auc_score

# XGBoost 커스텀 평가 함수
def xgb_roc_auc(y_pred, dtrain):
    y_true = dtrain.get_label()
    return "roc_auc", roc_auc_score(y_true, y_pred)

# %%
from sklearn.metrics import roc_auc_score
from lightgbm import early_stopping

def eval_function(max_depth, subsample, colsample_bytree, min_child_weight,
                 reg_alpha, gamma, reg_lambda, scale_pos_weight):
    '''최적화하려는 평가지표(roc_auc) 계산 함수'''
    # 베이지안 최적화를 수행할 하이퍼파라미터
    params = {'max_depth': int(round(max_depth)),
              'subsample': subsample,
              'colsample_bytree': colsample_bytree,
              'min_child_weight': min_child_weight,
              'gamma': gamma,
              'reg_alpha':reg_alpha,
              'reg_lambda': reg_lambda,
              'scale_pos_weight': scale_pos_weight}
    # 값이 고정된 하이퍼파라미터도 추가
    params.update(fixed_params)
    
    print('하이퍼파라미터 :', params)    
        
    # XGBoost 모델 훈련
    xgb_model = xgb.train(params=params, 
                          dtrain=bayes_dtrain,
                          num_boost_round=2000,
                          evals=[(bayes_dvalid, 'bayes_dvalid')],
                          maximize=True,
                          custom_metric=xgb_roc_auc, 
                          callbacks=[xgb.callback.EarlyStopping(rounds=100)],
                          verbose_eval=0)
                           
    best_iter = xgb_model.best_iteration # 최적 반복 횟수
    # 검증 데이터로 예측 수행
    preds = xgb_model.predict(bayes_dvalid, 
                              iteration_range=(0, best_iter))
    # roc_auc 계산
    roc_auc = roc_auc_score(bayes_dvalid.get_label(), preds)
    print(f'roc_auc : {roc_auc}\n')
    
    return roc_auc

# %%
from bayes_opt import BayesianOptimization

# 베이지안 최적화 객체 생성
optimizer = BayesianOptimization(f=eval_function, 
                                 pbounds=param_bounds, 
                                 random_state=0)

# %%
# 베이지안 최적화 수행
# TODO: init_points 10~15, n_iter 30~70
optimizer.maximize(init_points=10, n_iter=50)
# Out:
# |   iter    |  target   | colsam... |   gamma   | max_depth | min_ch... | reg_alpha | reg_la... | scale_... | subsample |
# -------------------------------------------------------------------------------------------------------------------------
# 하이퍼파라미터 : {'max_depth': 6, 'subsample': 0.867531900234624, 'colsample_bytree': 0.8646440511781974, 'min_child_weight': 6.0897663659937935, 'gamma': 10.14556809911726, 'reg_alpha': 7.84730959867781, 'reg_lambda': 1.3583576452266626, 'scale_pos_weight': 1.4875174422525386, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7360291247547385
#
# | 1         | 0.736     | 0.8646    | 10.15     | 6.411     | 6.09      | 7.847     | 1.358     | 1.488     | 0.8675    |
# 하이퍼파라미터 : {'max_depth': 7, 'subsample': 0.6261387899104622, 'colsample_bytree': 0.9890988281503088, 'min_child_weight': 6.0577898395058085, 'gamma': 9.150324556477333, 'reg_alpha': 8.136089122187865, 'reg_lambda': 1.4702386553170643, 'scale_pos_weight': 1.4142072116395774, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7369228910680347
#
# | 2         | 0.7369    | 0.9891    | 9.15      | 7.167     | 6.058     | 8.136     | 1.47      | 1.414     | 0.6261    |
# 하이퍼파라미터 : {'max_depth': 7, 'subsample': 0.8341587528859367, 'colsample_bytree': 0.7060655192320977, 'min_child_weight': 6.7400242964936385, 'gamma': 10.497859536643814, 'reg_alpha': 8.957236684465528, 'reg_lambda': 1.4196634256866894, 'scale_pos_weight': 1.4922958724505864, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7370964592969719
#
# | 3         | 0.7371    | 0.7061    | 10.5      | 7.113     | 6.74      | 8.957     | 1.42      | 1.492     | 0.8342    |
# 하이퍼파라미터 : {'max_depth': 5, 'subsample': 0.832270106830265, 'colsample_bytree': 0.7354823277606799, 'min_child_weight': 6.889337834099168, 'gamma': 9.919763063982572, 'reg_alpha': 8.043696643500143, 'reg_lambda': 1.2658647759962094, 'scale_pos_weight': 1.4529111224209252, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7343698764525494
#
# | 4         | 0.7344    | 0.7355    | 9.92      | 4.573     | 6.889     | 8.044     | 1.266     | 1.453     | 0.8323    |
# 하이퍼파라미터 : {'max_depth': 4, 'subsample': 0.804546089731045, 'colsample_bytree': 0.8368450996649646, 'min_child_weight': 6.235270994151755, 'gamma': 9.705301846605945, 'reg_alpha': 8.224191445444843, 'reg_lambda': 1.3467735987499028, 'scale_pos_weight': 1.5887496157029248, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7313428161360744
#
# | 5         | 0.7313    | 0.8368    | 9.705     | 4.075     | 6.235     | 8.224     | 1.347     | 1.589     | 0.8045    |
# 하이퍼파라미터 : {'max_depth': 7, 'subsample': 0.638677889296456, 'colsample_bytree': 0.8078523701721357, 'min_child_weight': 5.12045094325854, 'gamma': 9.311095861398025, 'reg_alpha': 8.333533430891336, 'reg_lambda': 1.3682551478472638, 'scale_pos_weight': 1.442076512214768, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7373226142670339
#
# | 6         | 0.7373    | 0.8079    | 9.311     | 6.791     | 5.12      | 8.334     | 1.368     | 1.442     | 0.6387    |
# 하이퍼파라미터 : {'max_depth': 6, 'subsample': 0.6483928553654988, 'colsample_bytree': 0.7946285052772551, 'min_child_weight': 5.877203026924641, 'gamma': 9.091132312827868, 'reg_alpha': 8.976747676118453, 'reg_lambda': 1.1408179242992114, 'scale_pos_weight': 1.4417753512189668, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7361128734241524
#
# | 7         | 0.7361    | 0.7946    | 9.091     | 6.281     | 5.877     | 8.977     | 1.141     | 1.442     | 0.6484    |
# 하이퍼파라미터 : {'max_depth': 6, 'subsample': 0.6414548854045842, 'colsample_bytree': 0.8959324976396195, 'min_child_weight': 5.488851184003206, 'gamma': 8.759874807619346, 'reg_alpha': 7.31793916729104, 'reg_lambda': 1.144150056465722, 'scale_pos_weight': 1.5312659178930548, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.736140196378192
#
# | 8         | 0.7361    | 0.8959    | 8.76      | 5.865     | 5.489     | 7.318     | 1.144     | 1.531     | 0.6415    |
# 하이퍼파라미터 : {'max_depth': 7, 'subsample': 0.7405953604943105, 'colsample_bytree': 0.758974708504016, 'min_child_weight': 5.194202551586122, 'gamma': 9.106175511982892, 'reg_alpha': 8.675889814997607, 'reg_lambda': 1.1384393631575853, 'scale_pos_weight': 1.5952918930026792, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7373696621846783
#
# | 9         | 0.7374    | 0.759     | 9.106     | 7.284     | 5.194     | 8.676     | 1.138     | 1.595     | 0.7406    |
# 하이퍼파라미터 : {'max_depth': 7, 'subsample': 0.6356183156862732, 'colsample_bytree': 0.9930283264571012, 'min_child_weight': 5.078375584508642, 'gamma': 9.814536559235139, 'reg_alpha': 7.565613925152819, 'reg_lambda': 1.1480786244852677, 'scale_pos_weight': 1.459228039504429, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7367539337541706
#
# | 10        | 0.7368    | 0.993     | 9.815     | 6.957     | 5.078     | 7.566     | 1.148     | 1.459     | 0.6356    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8400503635226737, 'colsample_bytree': 0.8951173546759559, 'min_child_weight': 5.066180665818833, 'gamma': 10.77489647849303, 'reg_alpha': 8.939104177527303, 'reg_lambda': 1.4212743917761685, 'scale_pos_weight': 1.4150009679604552, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7377782636902867
#
# | 11        | 0.7378    | 0.8951    | 10.77     | 7.964     | 5.066     | 8.939     | 1.421     | 1.415     | 0.8401    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8462834398047874, 'colsample_bytree': 0.7780377396574428, 'min_child_weight': 5.144342632944761, 'gamma': 8.061165386970966, 'reg_alpha': 7.180203945424472, 'reg_lambda': 1.4578288644785298, 'scale_pos_weight': 1.5592595708782588, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7381539185246273
#
# | 12        | 0.7382    | 0.778     | 8.061     | 7.817     | 5.144     | 7.18      | 1.458     | 1.559     | 0.8463    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8154863213488629, 'colsample_bytree': 0.7106815397745122, 'min_child_weight': 6.98081257890704, 'gamma': 8.105589245365518, 'reg_alpha': 7.098779136546568, 'reg_lambda': 1.4862616598403204, 'scale_pos_weight': 1.573932925708207, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7379615443562626
#
# | 13        | 0.738     | 0.7107    | 8.106     | 7.918     | 6.981     | 7.099     | 1.486     | 1.574     | 0.8155    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.6022487994221352, 'colsample_bytree': 0.8811705459829409, 'min_child_weight': 6.764017184063364, 'gamma': 10.892293667150906, 'reg_alpha': 7.019920767128431, 'reg_lambda': 1.3587139105555184, 'scale_pos_weight': 1.5901805912354257, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7377766418248476
#
# | 14        | 0.7378    | 0.8812    | 10.89     | 7.951     | 6.764     | 7.02      | 1.359     | 1.59      | 0.6022    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.7308257340953006, 'colsample_bytree': 0.8901947048955703, 'min_child_weight': 6.6408693296170975, 'gamma': 8.044662276814824, 'reg_alpha': 8.796463463292705, 'reg_lambda': 1.4781695884584631, 'scale_pos_weight': 1.5525590293012097, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7382691005848963
#
# | 15        | 0.7383    | 0.8902    | 8.045     | 7.879     | 6.641     | 8.796     | 1.478     | 1.553     | 0.7308    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.6279466505186425, 'colsample_bytree': 0.7217276821808507, 'min_child_weight': 5.071554136725226, 'gamma': 10.50482516854108, 'reg_alpha': 7.015523095074123, 'reg_lambda': 1.4790661824629545, 'scale_pos_weight': 1.566635161467958, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7376629720578547
#
# | 16        | 0.7377    | 0.7217    | 10.5      | 7.969     | 5.072     | 7.016     | 1.479     | 1.567     | 0.6279    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.6981387287341032, 'colsample_bytree': 0.8266200506697592, 'min_child_weight': 5.001383237232762, 'gamma': 8.050181607122477, 'reg_alpha': 8.502350297841886, 'reg_lambda': 1.1717959923278671, 'scale_pos_weight': 1.4145641401993183, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7381475376736242
#
# | 17        | 0.7381    | 0.8266    | 8.05      | 7.997     | 5.001     | 8.502     | 1.172     | 1.415     | 0.6981    |
# 하이퍼파라미터 : {'max_depth': 7, 'subsample': 0.8414668530005823, 'colsample_bytree': 0.8914146543273356, 'min_child_weight': 6.861819417793781, 'gamma': 8.023877234202011, 'reg_alpha': 7.8898897858937795, 'reg_lambda': 1.1566773298220308, 'scale_pos_weight': 1.4082883288294443, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7375578735979871
#
# | 18        | 0.7376    | 0.8914    | 8.024     | 6.813     | 6.862     | 7.89      | 1.157     | 1.408     | 0.8415    |
# 하이퍼파라미터 : {'max_depth': 7, 'subsample': 0.8187933732047548, 'colsample_bytree': 0.9860567348782523, 'min_child_weight': 5.040039461277765, 'gamma': 8.079165590465731, 'reg_alpha': 8.284967854645632, 'reg_lambda': 1.4454401392756937, 'scale_pos_weight': 1.4775549379803279, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7371219836881204
#
# | 19        | 0.7371    | 0.9861    | 8.079     | 6.846     | 5.04      | 8.285     | 1.445     | 1.478     | 0.8188    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.6162403399109943, 'colsample_bytree': 0.8198753564336303, 'min_child_weight': 6.990660464230614, 'gamma': 9.489211908693141, 'reg_alpha': 8.798704371975598, 'reg_lambda': 1.3508725001560387, 'scale_pos_weight': 1.4806966864718865, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7377536780660479
#
# | 20        | 0.7378    | 0.8199    | 9.489     | 7.954     | 6.991     | 8.799     | 1.351     | 1.481     | 0.6162    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8937711347006536, 'colsample_bytree': 0.757390183372155, 'min_child_weight': 6.859329338900456, 'gamma': 9.575376318014948, 'reg_alpha': 7.149108752050945, 'reg_lambda': 1.4791083441615633, 'scale_pos_weight': 1.457164917495886, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7380014513277194
#
# | 21        | 0.738     | 0.7574    | 9.575     | 7.971     | 6.859     | 7.149     | 1.479     | 1.457     | 0.8938    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.6499894240086, 'colsample_bytree': 0.7628834563071001, 'min_child_weight': 5.835656644229683, 'gamma': 8.005192023354724, 'reg_alpha': 7.904914459092742, 'reg_lambda': 1.1910482235227389, 'scale_pos_weight': 1.5156289625681332, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7378912128475592
#
# | 22        | 0.7379    | 0.7629    | 8.005     | 7.97      | 5.836     | 7.905     | 1.191     | 1.516     | 0.65      |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.7490665581027407, 'colsample_bytree': 0.7059338600798116, 'min_child_weight': 6.987816343916537, 'gamma': 8.422821573798036, 'reg_alpha': 8.391510350026355, 'reg_lambda': 1.1174273851806367, 'scale_pos_weight': 1.5303491088122878, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.73782786335605
#
# | 23        | 0.7378    | 0.7059    | 8.423     | 7.981     | 6.988     | 8.392     | 1.117     | 1.53      | 0.7491    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.7262222618618352, 'colsample_bytree': 0.8333190766366075, 'min_child_weight': 6.951194882139663, 'gamma': 10.754404240762312, 'reg_alpha': 8.22452329318112, 'reg_lambda': 1.2151505118546488, 'scale_pos_weight': 1.465332384600731, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7377797532794208
#
# | 24        | 0.7378    | 0.8333    | 10.75     | 7.976     | 6.951     | 8.225     | 1.215     | 1.465     | 0.7262    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.751146404024062, 'colsample_bytree': 0.7710396428086322, 'min_child_weight': 5.030358407032077, 'gamma': 9.242279552322861, 'reg_alpha': 8.586598475016663, 'reg_lambda': 1.4831876323748718, 'scale_pos_weight': 1.4674706251284981, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7379959055942829
#
# | 25        | 0.738     | 0.771     | 9.242     | 7.997     | 5.03      | 8.587     | 1.483     | 1.467     | 0.7511    |
# 하이퍼파라미터 : {'max_depth': 5, 'subsample': 0.797054204334147, 'colsample_bytree': 0.7201259457574264, 'min_child_weight': 6.895744955753339, 'gamma': 8.055388248851044, 'reg_alpha': 7.002894025131239, 'reg_lambda': 1.4955531677112388, 'scale_pos_weight': 1.4952866630503534, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7344335921717382
#
# | 26        | 0.7344    | 0.7201    | 8.055     | 5.476     | 6.896     | 7.003     | 1.496     | 1.495     | 0.7971    |
# 하이퍼파라미터 : {'max_depth': 7, 'subsample': 0.6054432538859765, 'colsample_bytree': 0.9427064857037222, 'min_child_weight': 6.991720714757816, 'gamma': 8.073816925422832, 'reg_alpha': 8.95963896840104, 'reg_lambda': 1.2262700348586062, 'scale_pos_weight': 1.5993371632638549, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7373544119112957
#
# | 27        | 0.7374    | 0.9427    | 8.074     | 7.245     | 6.992     | 8.96      | 1.226     | 1.599     | 0.6054    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.720655412345185, 'colsample_bytree': 0.7328058907779622, 'min_child_weight': 5.5378800199878375, 'gamma': 8.837369525878522, 'reg_alpha': 7.024421671152976, 'reg_lambda': 1.4448919236996154, 'scale_pos_weight': 1.4326366159498218, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7380038678381241
#
# | 28        | 0.738     | 0.7328    | 8.837     | 7.881     | 5.538     | 7.024     | 1.445     | 1.433     | 0.7207    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8879735211472204, 'colsample_bytree': 0.8773636306395451, 'min_child_weight': 5.6178416050675795, 'gamma': 8.255829381441007, 'reg_alpha': 8.966397936676872, 'reg_lambda': 1.370330265885559, 'scale_pos_weight': 1.595810401760505, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.738075471765909
#
# | 29        | 0.7381    | 0.8774    | 8.256     | 7.879     | 5.618     | 8.966     | 1.37      | 1.596     | 0.888     |
# 하이퍼파라미터 : {'max_depth': 6, 'subsample': 0.6117876255213185, 'colsample_bytree': 0.8543851887885571, 'min_child_weight': 6.941579706284578, 'gamma': 10.926481988586948, 'reg_alpha': 7.014559210810284, 'reg_lambda': 1.1332874680231277, 'scale_pos_weight': 1.4932919465191565, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7361711243551061
#
# | 30        | 0.7362    | 0.8544    | 10.93     | 6.48      | 6.942     | 7.015     | 1.133     | 1.493     | 0.6118    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.809483857947186, 'colsample_bytree': 0.7997600798423508, 'min_child_weight': 5.025168603448961, 'gamma': 9.160836544715886, 'reg_alpha': 7.027926572250185, 'reg_lambda': 1.1454901064621854, 'scale_pos_weight': 1.5716932858863628, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7380331384126816
#
# | 31        | 0.738     | 0.7998    | 9.161     | 7.984     | 5.025     | 7.028     | 1.145     | 1.572     | 0.8095    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8974257688265972, 'colsample_bytree': 0.7713440695940645, 'min_child_weight': 6.010372215898519, 'gamma': 10.866573451044385, 'reg_alpha': 8.126215710235769, 'reg_lambda': 1.47188153672711, 'scale_pos_weight': 1.4973728270233053, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7378073368375236
#
# | 32        | 0.7378    | 0.7713    | 10.87     | 8.0       | 6.01      | 8.126     | 1.472     | 1.497     | 0.8974    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8849148098976377, 'colsample_bytree': 0.8971390145872449, 'min_child_weight': 6.893018202727307, 'gamma': 8.055208971424163, 'reg_alpha': 7.898365775432922, 'reg_lambda': 1.411217208383229, 'scale_pos_weight': 1.419770518223976, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7381821447086586
#
# | 33        | 0.7382    | 0.8971    | 8.055     | 7.841     | 6.893     | 7.898     | 1.411     | 1.42      | 0.8849    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.7830812936666329, 'colsample_bytree': 0.9923802105101294, 'min_child_weight': 5.1582139253624195, 'gamma': 8.043188066989186, 'reg_alpha': 7.023993490253259, 'reg_lambda': 1.1492169855670915, 'scale_pos_weight': 1.5444682991869356, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7378632581260938
#
# | 34        | 0.7379    | 0.9924    | 8.043     | 7.873     | 5.158     | 7.024     | 1.149     | 1.544     | 0.7831    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8466666579223713, 'colsample_bytree': 0.7723223482050394, 'min_child_weight': 6.263518352683025, 'gamma': 8.162122107010955, 'reg_alpha': 8.994060099942786, 'reg_lambda': 1.1177055470728516, 'scale_pos_weight': 1.4485174140930563, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7380115290053014
#
# | 35        | 0.738     | 0.7723    | 8.162     | 7.995     | 6.264     | 8.994     | 1.118     | 1.449     | 0.8467    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.6395440000163212, 'colsample_bytree': 0.9087983899158869, 'min_child_weight': 6.9428808512561115, 'gamma': 10.971295518290097, 'reg_alpha': 8.97942700754947, 'reg_lambda': 1.3714286195213368, 'scale_pos_weight': 1.5290921328980656, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7376071948912286
#
# | 36        | 0.7376    | 0.9088    | 10.97     | 7.904     | 6.943     | 8.979     | 1.371     | 1.529     | 0.6395    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.7882057696102495, 'colsample_bytree': 0.792475635470251, 'min_child_weight': 5.025593991060806, 'gamma': 8.728359796711718, 'reg_alpha': 7.884157387625883, 'reg_lambda': 1.4253880246825177, 'scale_pos_weight': 1.5236605130621952, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.738042916000736
#
# | 37        | 0.738     | 0.7925    | 8.728     | 7.968     | 5.026     | 7.884     | 1.425     | 1.524     | 0.7882    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8655626277169066, 'colsample_bytree': 0.7456726574986081, 'min_child_weight': 5.6381419661497585, 'gamma': 9.942025763035536, 'reg_alpha': 8.893377708396052, 'reg_lambda': 1.4117036023078404, 'scale_pos_weight': 1.5043089813886896, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7377898615582374
#
# | 38        | 0.7378    | 0.7457    | 9.942     | 7.989     | 5.638     | 8.893     | 1.412     | 1.504     | 0.8656    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.9, 'colsample_bytree': 0.7, 'min_child_weight': 6.143449400483323, 'gamma': 8.0, 'reg_alpha': 7.0, 'reg_lambda': 1.1, 'scale_pos_weight': 1.6, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7381142968356487
#
# | 39        | 0.7381    | 0.7       | 8.0       | 8.0       | 6.143     | 7.0       | 1.1       | 1.6       | 0.9       |
# 하이퍼파라미터 : {'max_depth': 7, 'subsample': 0.9, 'colsample_bytree': 0.7, 'min_child_weight': 5.986522269577627, 'gamma': 8.0, 'reg_alpha': 7.0, 'reg_lambda': 1.5, 'scale_pos_weight': 1.4, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.737505731068334
#
# | 40        | 0.7375    | 0.7       | 8.0       | 7.366     | 5.987     | 7.0       | 1.5       | 1.4       | 0.9       |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.7787647307925909, 'colsample_bytree': 0.9714962471508661, 'min_child_weight': 5.27771610222591, 'gamma': 8.052039567065608, 'reg_alpha': 8.75355583114742, 'reg_lambda': 1.4491662317003808, 'scale_pos_weight': 1.411416489574225, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7380376812153294
#
# | 41        | 0.738     | 0.9715    | 8.052     | 7.987     | 5.278     | 8.754     | 1.449     | 1.411     | 0.7788    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8976703021641026, 'colsample_bytree': 0.728949169211708, 'min_child_weight': 5.854614153095957, 'gamma': 9.681234266030526, 'reg_alpha': 7.026011736218553, 'reg_lambda': 1.2919435995350532, 'scale_pos_weight': 1.5085464082002316, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7380656527181171
#
# | 42        | 0.7381    | 0.7289    | 9.681     | 7.94      | 5.855     | 7.026     | 1.292     | 1.509     | 0.8977    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.7712774045613848, 'colsample_bytree': 0.7325776760500816, 'min_child_weight': 5.1405171742331515, 'gamma': 8.407265675391569, 'reg_alpha': 8.880900603940967, 'reg_lambda': 1.4740273201521885, 'scale_pos_weight': 1.562346571361412, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7379697257444298
#
# | 43        | 0.738     | 0.7326    | 8.407     | 7.982     | 5.141     | 8.881     | 1.474     | 1.562     | 0.7713    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.9, 'colsample_bytree': 0.7, 'min_child_weight': 7.0, 'gamma': 10.174771900901183, 'reg_alpha': 9.0, 'reg_lambda': 1.5, 'scale_pos_weight': 1.4, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7376522863041253
#
# | 44        | 0.7377    | 0.7       | 10.17     | 8.0       | 7.0       | 9.0       | 1.5       | 1.4       | 0.9       |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8023266680812927, 'colsample_bytree': 0.9887668490756211, 'min_child_weight': 6.845306929209221, 'gamma': 8.95092471820318, 'reg_alpha': 7.00334627051823, 'reg_lambda': 1.2234559464073131, 'scale_pos_weight': 1.5002903238365324, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7379463394911638
#
# | 45        | 0.7379    | 0.9888    | 8.951     | 7.983     | 6.845     | 7.003     | 1.223     | 1.5       | 0.8023    |
# 하이퍼파라미터 : {'max_depth': 7, 'subsample': 0.610551885488759, 'colsample_bytree': 0.7312754216407512, 'min_child_weight': 5.052520325515833, 'gamma': 10.978672147496342, 'reg_alpha': 8.849390722643149, 'reg_lambda': 1.4062980022127551, 'scale_pos_weight': 1.4269145346449523, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.736899618335478
#
# | 46        | 0.7369    | 0.7313    | 10.98     | 6.871     | 5.053     | 8.849     | 1.406     | 1.427     | 0.6106    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8536918643026272, 'colsample_bytree': 0.8620669674756596, 'min_child_weight': 6.523874091613588, 'gamma': 8.474419490662395, 'reg_alpha': 8.923791923143636, 'reg_lambda': 1.4931649823071376, 'scale_pos_weight': 1.5967583308258697, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7381449474271775
#
# | 47        | 0.7381    | 0.8621    | 8.474     | 7.901     | 6.524     | 8.924     | 1.493     | 1.597     | 0.8537    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8667768053286036, 'colsample_bytree': 0.7168356875114089, 'min_child_weight': 5.090258666328389, 'gamma': 10.348233817742265, 'reg_alpha': 7.938320458554515, 'reg_lambda': 1.108811902705084, 'scale_pos_weight': 1.5726298042572437, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7377654141331229
#
# | 48        | 0.7378    | 0.7168    | 10.35     | 7.931     | 5.09      | 7.938     | 1.109     | 1.573     | 0.8668    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8265027730038561, 'colsample_bytree': 0.9944961466681765, 'min_child_weight': 6.554652966649781, 'gamma': 9.565904105430498, 'reg_alpha': 8.014911225719013, 'reg_lambda': 1.4693639342033071, 'scale_pos_weight': 1.5889843450238414, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7375688762225663
#
# | 49        | 0.7376    | 0.9945    | 9.566     | 7.989     | 6.555     | 8.015     | 1.469     | 1.589     | 0.8265    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8959638474715523, 'colsample_bytree': 0.9984384598298863, 'min_child_weight': 5.990074822603564, 'gamma': 8.088009755997444, 'reg_alpha': 8.642364685640842, 'reg_lambda': 1.3976241459996548, 'scale_pos_weight': 1.4854885389725734, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7375165678539637
#
# | 50        | 0.7375    | 0.9984    | 8.088     | 7.959     | 5.99      | 8.642     | 1.398     | 1.485     | 0.896     |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.6349446851415996, 'colsample_bytree': 0.7472749585306869, 'min_child_weight': 6.965769716050699, 'gamma': 8.06850517165096, 'reg_alpha': 7.515500603316026, 'reg_lambda': 1.167284463066955, 'scale_pos_weight': 1.4330431990371062, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7379992026305373
#
# | 51        | 0.738     | 0.7473    | 8.069     | 7.951     | 6.966     | 7.516     | 1.167     | 1.433     | 0.6349    |
# 하이퍼파라미터 : {'max_depth': 7, 'subsample': 0.6712475858413389, 'colsample_bytree': 0.7158275981171837, 'min_child_weight': 5.4886109089302195, 'gamma': 8.072617205366384, 'reg_alpha': 8.938952728455991, 'reg_lambda': 1.4364127450913395, 'scale_pos_weight': 1.5327835624119956, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7372676712308375
#
# | 52        | 0.7373    | 0.7158    | 8.073     | 7.467     | 5.489     | 8.939     | 1.436     | 1.533     | 0.6712    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8998753955950956, 'colsample_bytree': 0.704040552608102, 'min_child_weight': 6.37709390387713, 'gamma': 8.765808759383663, 'reg_alpha': 7.1792055013735565, 'reg_lambda': 1.478195000701432, 'scale_pos_weight': 1.587578236591833, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7380402951530547
#
# | 53        | 0.738     | 0.704     | 8.766     | 7.979     | 6.377     | 7.179     | 1.478     | 1.588     | 0.8999    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.8030913269842392, 'colsample_bytree': 0.9986925280692385, 'min_child_weight': 6.936555703153817, 'gamma': 8.477936423237399, 'reg_alpha': 8.991687601232716, 'reg_lambda': 1.3386507746344465, 'scale_pos_weight': 1.5963824447911135, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7377098413037737
#
# | 54        | 0.7377    | 0.9987    | 8.478     | 7.971     | 6.937     | 8.992     | 1.339     | 1.596     | 0.8031    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.6911687804755415, 'colsample_bytree': 0.825047854572006, 'min_child_weight': 6.321781899902051, 'gamma': 10.270103880483777, 'reg_alpha': 7.065608658821136, 'reg_lambda': 1.1113781286413347, 'scale_pos_weight': 1.4835500194081035, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7379384947165785
#
# | 55        | 0.7379    | 0.825     | 10.27     | 7.924     | 6.322     | 7.066     | 1.111     | 1.484     | 0.6912    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.6663344883708014, 'colsample_bytree': 0.9847001253666501, 'min_child_weight': 5.613118936961787, 'gamma': 9.046959336298634, 'reg_alpha': 8.989773964591892, 'reg_lambda': 1.4490845789626405, 'scale_pos_weight': 1.4101628267930655, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7378024653183868
#
# | 56        | 0.7378    | 0.9847    | 9.047     | 7.933     | 5.613     | 8.99      | 1.449     | 1.41      | 0.6663    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.6831820775479074, 'colsample_bytree': 0.7030510705233084, 'min_child_weight': 6.5695264806019615, 'gamma': 8.181713414414306, 'reg_alpha': 8.935802188668289, 'reg_lambda': 1.4304907896311438, 'scale_pos_weight': 1.4487274125033063, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7377124453701329
#
# | 57        | 0.7377    | 0.7031    | 8.182     | 7.994     | 6.57      | 8.936     | 1.43      | 1.449     | 0.6832    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.6046273188104847, 'colsample_bytree': 0.7068530671094465, 'min_child_weight': 6.051235823942257, 'gamma': 10.98004135745483, 'reg_alpha': 7.398814156583899, 'reg_lambda': 1.1053580138116466, 'scale_pos_weight': 1.5142639678586243, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7373649673629935
#
# | 58        | 0.7374    | 0.7069    | 10.98     | 7.962     | 6.051     | 7.399     | 1.105     | 1.514     | 0.6046    |
# 하이퍼파라미터 : {'max_depth': 8, 'subsample': 0.6450632051603269, 'colsample_bytree': 0.7031566479509698, 'min_child_weight': 5.628228261515627, 'gamma': 10.992030489244879, 'reg_alpha': 8.992643954045619, 'reg_lambda': 1.2217871844022568, 'scale_pos_weight': 1.5754025036849186, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7372460420807252
#
# | 59        | 0.7372    | 0.7032    | 10.99     | 7.962     | 5.628     | 8.993     | 1.222     | 1.575     | 0.6451    |
# 하이퍼파라미터 : {'max_depth': 7, 'subsample': 0.7046803811903798, 'colsample_bytree': 0.7562284060262771, 'min_child_weight': 5.0004985767510135, 'gamma': 8.058978521902299, 'reg_alpha': 7.064608456235165, 'reg_lambda': 1.2743337441580953, 'scale_pos_weight': 1.5646765777373584, 'objective': 'binary:logistic', 'learning_rate': 0.02, 'random_state': 1991}
# roc_auc : 0.7376912949812731
#
# | 60        | 0.7377    | 0.7562    | 8.059     | 6.972     | 5.0       | 7.065     | 1.274     | 1.565     | 0.7047    |
# =========================================================================================================================

# %%
# 평가함수 점수가 최대일 때 하이퍼파라미터
max_params = optimizer.max['params']
max_params
# Out:
# {'colsample_bytree': 0.8901947048955703,
#  'gamma': 8.044662276814824,
#  'max_depth': 7.8794385562808245,
#  'min_child_weight': 6.6408693296170975,
#  'reg_alpha': 8.796463463292705,
#  'reg_lambda': 1.4781695884584631,
#  'scale_pos_weight': 1.5525590293012097,
#  'subsample': 0.7308257340953006}

# %%
# 정수형 하이퍼파라미터 변환
max_params['max_depth'] = int(round(max_params['max_depth']))

# 값이 고정된 하이퍼파라미터 추가
max_params.update(fixed_params)

# %%
max_params
# Out:
# {'colsample_bytree': 0.8901947048955703,
#  'gamma': 8.044662276814824,
#  'max_depth': 8,
#  'min_child_weight': 6.6408693296170975,
#  'reg_alpha': 8.796463463292705,
#  'reg_lambda': 1.4781695884584631,
#  'scale_pos_weight': 1.5525590293012097,
#  'subsample': 0.7308257340953006,
#  'objective': 'binary:logistic',
#  'learning_rate': 0.02,
#  'random_state': 1991}

# %% [markdown]
# ### 4-2. 모델 훈련 및 성능 검증 (층화 K 폴드)

# %%
from sklearn.model_selection import StratifiedKFold

# 층화 K 폴드 교차 검증기 생성
folds = StratifiedKFold(n_splits=5, shuffle=True, random_state=1991)

# OOF 방식으로 훈련된 모델로 검증 데이터 타깃값을 예측한 확률을 담을 1차원 배열
oof_val_preds = np.zeros(X.shape[0]) 
# OOF 방식으로 훈련된 모델로 테스트 데이터 타깃값을 예측한 확률을 담을 1차원 배열
oof_test_preds = np.zeros(X_test.shape[0]) 

# OOF 방식으로 모델 훈련, 검증, 예측
for idx, (train_idx, valid_idx) in enumerate(folds.split(X, y)):
    # 각 폴드를 구분하는 문구 출력
    print('#'*40, f'폴드 {idx+1} / 폴드 {folds.n_splits}', '#'*40)
    
    # 훈련용 데이터, 검증용 데이터 설정
    X_train, y_train = X[train_idx], y[train_idx]
    X_valid, y_valid = X[valid_idx], y[valid_idx]

    # XGBoost 전용 데이터셋 생성 
    dtrain = xgb.DMatrix(X_train, y_train)
    dvalid = xgb.DMatrix(X_valid, y_valid)
    dtest = xgb.DMatrix(X_test)
    # XGBoost 모델 훈련
    xgb_model = xgb.train(params=max_params, 
                          dtrain=dtrain,
                          num_boost_round=2000,
                          evals=[(dvalid, 'valid')],
                          maximize=True,
                          custom_metric=xgb_roc_auc, 
                          callbacks=[xgb.callback.EarlyStopping(rounds=100)],
                          verbose_eval=0)

    # 모델 성능이 가장 좋을 때의 부스팅 반복 횟수 저장
    best_iter = xgb_model.best_iteration
    # 테스트 데이터를 활용해 OOF 예측
    oof_test_preds += xgb_model.predict(dtest,
                                        iteration_range=(0, best_iter))/folds.n_splits
    
    # 모델 성능 평가를 위한 검증 데이터 타깃값 예측 
    oof_val_preds[valid_idx] += xgb_model.predict(dvalid, 
                                                  iteration_range=(0, best_iter))
    
    # 검증 데이터 예측 확률에 대한 ROC-AUC
    roc_auc = roc_auc_score(dvalid.get_label(), oof_val_preds[valid_idx])
    print(f'폴드 {idx+1} roc-auc : {roc_auc}\n')
# Out:
# ######################################## 폴드 1 / 폴드 5 ########################################
# 폴드 1 roc-auc : 0.7352618060525237
#
# ######################################## 폴드 2 / 폴드 5 ########################################
# 폴드 2 roc-auc : 0.7328786305923686
#
# ######################################## 폴드 3 / 폴드 5 ########################################
# 폴드 3 roc-auc : 0.7352820622025257
#
# ######################################## 폴드 4 / 폴드 5 ########################################
# 폴드 4 roc-auc : 0.7394325604379208
#
# ######################################## 폴드 5 / 폴드 5 ########################################
# 폴드 5 roc-auc : 0.7397459566768689

# %% [markdown]
# ## 5. 최종 결과

# %%
print('OOF 검증 데이터 roc-auc :', roc_auc_score(y, oof_val_preds))
# Out:
# OOF 검증 데이터 roc-auc : 0.7364637620111585

# %%
submission['probability'] = oof_test_preds
submission.to_csv('xgb_submission.csv')

# %%
submission = pd.read_csv('/kaggle/working/xgb_submission.csv')
submission.head()
# Out:
#            ID  probability
# 0  TEST_00000     0.051381
# 1  TEST_00001     0.048562
# 2  TEST_00002     0.241765
# 3  TEST_00003     0.179002
# 4  TEST_00004     0.570247
