# %% [markdown]
# # CatBoost - 베이스라인 버전 (one-hot encoding)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/lg-aimers/sample_submission.csv
# /kaggle/input/lg-aimers/train.csv
# /kaggle/input/lg-aimers/test.csv

# %%
data_path = '/kaggle/input/lg-aimers/'

train = pd.read_csv(data_path + 'train.csv', index_col= 'ID')
test = pd.read_csv(data_path + 'test.csv', index_col= 'ID')
submission = pd.read_csv(data_path + 'sample_submission.csv', index_col= 'ID')

# %% [markdown]
# ## 1. 데이터 통합

# %%
all_data = pd.concat([train, test], ignore_index= True)
all_data = all_data.drop('임신 성공 여부', axis= 1)

# %% [markdown]
# ## 2. 피처 엔지니어링

# %%
categorical_columns = [
    "시술 시기 코드",
    "시술 당시 나이",
    "시술 유형",
    "특정 시술 유형",
    "배란 자극 여부",
    "배란 유도 유형",
    "단일 배아 이식 여부",
    "착상 전 유전 검사 사용 여부",
    "착상 전 유전 진단 사용 여부",
    "남성 주 불임 원인",
    "남성 부 불임 원인",
    "여성 주 불임 원인",
    "여성 부 불임 원인",
    "부부 주 불임 원인",
    "부부 부 불임 원인",
    "불명확 불임 원인",
    "불임 원인 - 난관 질환",
    "불임 원인 - 남성 요인",
    "불임 원인 - 배란 장애",
    "불임 원인 - 여성 요인",
    "불임 원인 - 자궁경부 문제",
    "불임 원인 - 자궁내막증",
    "불임 원인 - 정자 농도",
    "불임 원인 - 정자 면역학적 요인",
    "불임 원인 - 정자 운동성",
    "불임 원인 - 정자 형태",
    "배아 생성 주요 이유",
    "총 시술 횟수",
    "클리닉 내 총 시술 횟수",
    "IVF 시술 횟수",
    "DI 시술 횟수",
    "총 임신 횟수",
    "IVF 임신 횟수",
    "DI 임신 횟수",
    "총 출산 횟수",
    "IVF 출산 횟수",
    "DI 출산 횟수",
    "난자 출처",
    "정자 출처",
    "난자 기증자 나이",
    "정자 기증자 나이",
    "동결 배아 사용 여부",
    "신선 배아 사용 여부",
    "기증 배아 사용 여부",
    "대리모 여부",
    "PGD 시술 여부",
    "PGS 시술 여부"
]

# %%
# 카테고리형 컬럼들을 문자열로 변환
for col in categorical_columns:
    all_data[col] = all_data[col].astype(str)

# %%
from sklearn.preprocessing import OneHotEncoder

onehot_encoder = OneHotEncoder()

encoded_cat_matrix = onehot_encoder.fit_transform(all_data[categorical_columns])

encoded_cat_matrix
# Out:
# <346418x205 sparse matrix of type '<class 'numpy.float64'>'
# 	with 16281646 stored elements in Compressed Sparse Row format>

# %%
numeric_columns = [
    "임신 시도 또는 마지막 임신 경과 연수",
    "총 생성 배아 수",
    "미세주입된 난자 수",
    "미세주입에서 생성된 배아 수",
    "이식된 배아 수",
    "미세주입 배아 이식 수",
    "저장된 배아 수",
    "미세주입 후 저장된 배아 수",
    "해동된 배아 수",
    "해동 난자 수",
    "수집된 신선 난자 수",
    "저장된 신선 난자 수",
    "혼합된 난자 수",
    "파트너 정자와 혼합된 난자 수",
    "기증자 정자와 혼합된 난자 수",
    "난자 채취 경과일",
    "난자 해동 경과일",
    "난자 혼합 경과일",
    "배아 이식 경과일",
    "배아 해동 경과일"
]

# %%
all_columns = all_data.columns
all_columns
# Out:
# Index(['시술 시기 코드', '시술 당시 나이', '임신 시도 또는 마지막 임신 경과 연수', '시술 유형', '특정 시술 유형',
#        '배란 자극 여부', '배란 유도 유형', '단일 배아 이식 여부', '착상 전 유전 검사 사용 여부',
#        '착상 전 유전 진단 사용 여부', '남성 주 불임 원인', '남성 부 불임 원인', '여성 주 불임 원인',
#        '여성 부 불임 원인', '부부 주 불임 원인', '부부 부 불임 원인', '불명확 불임 원인', '불임 원인 - 난관 질환',
#        '불임 원인 - 남성 요인', '불임 원인 - 배란 장애', '불임 원인 - 여성 요인', '불임 원인 - 자궁경부 문제',
#        '불임 원인 - 자궁내막증', '불임 원인 - 정자 농도', '불임 원인 - 정자 면역학적 요인',
#        '불임 원인 - 정자 운동성', '불임 원인 - 정자 형태', '배아 생성 주요 이유', '총 시술 횟수',
#        '클리닉 내 총 시술 횟수', 'IVF 시술 횟수', 'DI 시술 횟수', '총 임신 횟수', 'IVF 임신 횟수',
#        'DI 임신 횟수', '총 출산 횟수', 'IVF 출산 횟수', 'DI 출산 횟수', '총 생성 배아 수',
#        '미세주입된 난자 수', '미세주입에서 생성된 배아 수', '이식된 배아 수', '미세주입 배아 이식 수', '저장된 배아 수',
#        '미세주입 후 저장된 배아 수', '해동된 배아 수', '해동 난자 수', '수집된 신선 난자 수', '저장된 신선 난자 수',
#        '혼합된 난자 수', '파트너 정자와 혼합된 난자 수', '기증자 정자와 혼합된 난자 수', '난자 출처', '정자 출처',
#        '난자 기증자 나이', '정자 기증자 나이', '동결 배아 사용 여부', '신선 배아 사용 여부', '기증 배아 사용 여부',
#        '대리모 여부', 'PGD 시술 여부', 'PGS 시술 여부', '난자 채취 경과일', '난자 해동 경과일',
#        '난자 혼합 경과일', '배아 이식 경과일', '배아 해동 경과일'],
#       dtype='object')

# %%
len(all_columns)
# Out:
# 67

# %%
from scipy import sparse

extracted_data_sprs = sparse.hstack([sparse.csr_matrix(all_data[numeric_columns]),
                               encoded_cat_matrix],
                              format='csr')

# %% [markdown]
# ## 3. 데이터 나누기

# %%
num_train = len(train) 

X = extracted_data_sprs[:num_train]
X_test = extracted_data_sprs[num_train:]

y = train['임신 성공 여부'].values

# %% [markdown]
# ## 5. 파라미터 최적화

# %%
from catboost import CatBoostClassifier, Pool
from sklearn.model_selection import train_test_split

# 8:2 비율로 훈련 데이터, 검증 데이터 분리 (베이지안 최적화 수행용)
X_train, X_valid, y_train, y_valid = train_test_split(X, y, 
                                                      test_size=0.2, 
                                                      random_state=0)

# CatBoost 전용 데이터셋
bayes_dtrain = Pool(X_train, y_train, cat_features=None)
bayes_dvalid = Pool(X_valid, y_valid, cat_features=None)

# %%
# 베이지안 최적화를 위한 하이퍼파라미터 범위
param_bounds = {
    'depth': (6, 10),
    'learning_rate': (0.05, 0.1),
    'l2_leaf_reg': (8, 10),
    'bagging_temperature': (0.5, 1.0),
    'border_count': (200, 255)
}

# 고정된 하이퍼파라미터
fixed_params = {
    'loss_function': 'Logloss',
    'eval_metric': 'AUC',
    'iterations': 2500,
    'random_seed': 1991,
    'verbose': 200
}

# %%
from sklearn.metrics import roc_auc_score

# 평가 함수 정의
def eval_function(depth, learning_rate, l2_leaf_reg, bagging_temperature, border_count):
    params = {
        'depth': int(round(depth)),
        'learning_rate': learning_rate,
        'l2_leaf_reg': l2_leaf_reg,
        'bagging_temperature': bagging_temperature,
        'border_count': int(round(border_count))
    }
    
    params.update(fixed_params)
    print('하이퍼파라미터:', params)
    
    # CatBoost 모델 훈련
    cat_model = CatBoostClassifier(**params)
    cat_model.fit(bayes_dtrain, 
                  eval_set=bayes_dvalid, 
                  early_stopping_rounds=200, 
                  verbose=0)
    
    # 검증 데이터 예측
    preds = cat_model.predict_proba(X_valid)[:, 1]
    
    # ROC-AUC 계산
    roc_auc = roc_auc_score(y_valid, preds)
    print(f'ROC-AUC : {roc_auc}\n')
    
    return roc_auc

# %%
from bayes_opt import BayesianOptimization

# 베이지안 최적화 객체 생성
optimizer = BayesianOptimization(f=eval_function,      # 평가지표 계산 함수
                                 pbounds=param_bounds, # 하이퍼파라미터 범위
                                 random_state=0)

# %%
# 베이지안 최적화 수행
# TODO: init_points 10~15, n_iter 30~70
optimizer.maximize(init_points=15, n_iter=60)
# Out:
# |   iter    |  target   | baggin... | border... |   depth   | l2_lea... | learni... |
# -------------------------------------------------------------------------------------
# 하이퍼파라미터: {'depth': 8, 'learning_rate': 0.07118273996694524, 'l2_leaf_reg': 9.089766365993794, 'bagging_temperature': 0.7744067519636624, 'border_count': 239, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.741458709724407
#
# | 1         | 0.7415    | 0.7744    | 239.3     | 8.411     | 9.09      | 0.07118   |
# 하이퍼파라미터: {'depth': 10, 'learning_rate': 0.0691720759412889, 'l2_leaf_reg': 9.927325521002059, 'bagging_temperature': 0.8229470565333281, 'border_count': 224, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7409852454468769
#
# | 2         | 0.741     | 0.8229    | 224.1     | 9.567     | 9.927     | 0.06917   |
# 하이퍼파라미터: {'depth': 8, 'learning_rate': 0.05355180290989435, 'l2_leaf_reg': 9.851193276585322, 'bagging_temperature': 0.8958625190413323, 'border_count': 229, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7416650824769412
#
# | 3         | 0.7417    | 0.8959    | 229.1     | 8.272     | 9.851     | 0.05355   |
# 하이퍼파라미터: {'depth': 9, 'learning_rate': 0.09350060741234097, 'l2_leaf_reg': 9.556313501899702, 'bagging_temperature': 0.5435646498507704, 'border_count': 201, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7407185023811017
#
# | 4         | 0.7407    | 0.5436    | 201.1     | 9.33      | 9.556     | 0.0935    |
# 하이퍼파라미터: {'depth': 8, 'learning_rate': 0.05591372129344666, 'l2_leaf_reg': 9.56105835257291, 'bagging_temperature': 0.989309171116382, 'border_count': 244, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.74162830374138
#
# | 5         | 0.7416    | 0.9893    | 244.0     | 7.846     | 9.561     | 0.05591   |
# 하이퍼파라미터: {'depth': 10, 'learning_rate': 0.07073309699952618, 'l2_leaf_reg': 9.043696643500143, 'bagging_temperature': 0.819960510663762, 'border_count': 208, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7406639285339951
#
# | 6         | 0.7407    | 0.82      | 207.9     | 9.779     | 9.044     | 0.07073   |
# 하이퍼파라미터: {'depth': 8, 'learning_rate': 0.05093949002181776, 'l2_leaf_reg': 9.136867897737297, 'bagging_temperature': 0.6322778060523135, 'border_count': 243, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7416643421244891
#
# | 7         | 0.7417    | 0.6323    | 242.6     | 7.825     | 9.137     | 0.05094   |
# 하이퍼파라미터: {'depth': 8, 'learning_rate': 0.08409101495517418, 'l2_leaf_reg': 9.887496157029249, 'bagging_temperature': 0.8088177485379385, 'border_count': 234, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7413151810494412
#
# | 8         | 0.7413    | 0.8088    | 233.7     | 8.468     | 9.887     | 0.08409   |
# 하이퍼파라미터: {'depth': 9, 'learning_rate': 0.08333833577228339, 'l2_leaf_reg': 8.12045094325854, 'bagging_temperature': 0.679753950286893, 'border_count': 224, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7410809641347409
#
# | 9         | 0.7411    | 0.6798    | 224.0     | 8.791     | 8.12      | 0.08334   |
# 하이퍼파라미터: {'depth': 7, 'learning_rate': 0.06818553854713114, 'l2_leaf_reg': 8.630856701848368, 'bagging_temperature': 0.8353189348090797, 'border_count': 212, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7417988167825306
#
# | 10        | 0.7418    | 0.8353    | 211.6     | 6.516     | 8.631     | 0.06819   |
# 하이퍼파라미터: {'depth': 10, 'learning_rate': 0.06044383780474174, 'l2_leaf_reg': 8.204089621496056, 'bagging_temperature': 0.7850983852089398, 'border_count': 224, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.741109708565489
#
# | 11        | 0.7411    | 0.7851    | 224.1     | 9.953     | 8.204     | 0.06044   |
# 하이퍼파라미터: {'depth': 7, 'learning_rate': 0.06222127960008014, 'l2_leaf_reg': 8.932621545712612, 'bagging_temperature': 0.5806547589424982, 'border_count': 236, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7417350842820193
#
# | 12        | 0.7417    | 0.5807    | 235.9     | 7.013     | 8.933     | 0.06222   |
# 하이퍼파라미터: {'depth': 9, 'learning_rate': 0.05982911808400268, 'l2_leaf_reg': 8.276365902697227, 'bagging_temperature': 0.5794847918227599, 'border_count': 206, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7414813013327074
#
# | 13        | 0.7415    | 0.5795    | 206.1     | 8.625     | 8.276     | 0.05983   |
# 하이퍼파라미터: {'depth': 6, 'learning_rate': 0.054804920394698156, 'l2_leaf_reg': 9.675889814997607, 'bagging_temperature': 0.684362585330482, 'border_count': 245, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.741854157634778
#
# | 14        | 0.7419    | 0.6844    | 245.2     | 6.388     | 9.676     | 0.0548    |
# 하이퍼파라미터: {'depth': 10, 'learning_rate': 0.0869631789699151, 'l2_leaf_reg': 9.209691039490092, 'bagging_temperature': 0.9882297325066979, 'border_count': 226, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7408207065564488
#
# | 15        | 0.7408    | 0.9882    | 225.8     | 9.907     | 9.21      | 0.08696   |
# 하이퍼파라미터: {'depth': 6, 'learning_rate': 0.08569518026234241, 'l2_leaf_reg': 8.22034322194806, 'bagging_temperature': 0.9504684531810298, 'border_count': 243, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7418167481189273
#
# | 16        | 0.7418    | 0.9505    | 243.5     | 6.032     | 8.22      | 0.0857    |
# 하이퍼파라미터: {'depth': 6, 'learning_rate': 0.05445618550977576, 'l2_leaf_reg': 8.00685195210411, 'bagging_temperature': 0.974493004759496, 'border_count': 247, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7418131371732328
#
# | 17        | 0.7418    | 0.9745    | 246.5     | 6.032     | 8.007     | 0.05446   |
# 하이퍼파라미터: {'depth': 6, 'learning_rate': 0.07863304398526644, 'l2_leaf_reg': 8.140751436500732, 'bagging_temperature': 0.8328517617071187, 'border_count': 214, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7402494742954663
#
# | 18        | 0.7402    | 0.8329    | 214.3     | 6.156     | 8.141     | 0.07863   |
# 하이퍼파라미터: {'depth': 6, 'learning_rate': 0.05143762640060021, 'l2_leaf_reg': 8.246574757449189, 'bagging_temperature': 0.8705562414662174, 'border_count': 210, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7417683290685412
#
# | 19        | 0.7418    | 0.8706    | 209.5     | 6.051     | 8.247     | 0.05144   |
# 하이퍼파라미터: {'depth': 6, 'learning_rate': 0.07028473691668123, 'l2_leaf_reg': 9.988412951855635, 'bagging_temperature': 0.6435011123262282, 'border_count': 248, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7416043785115288
#
# | 20        | 0.7416    | 0.6435    | 247.8     | 6.289     | 9.988     | 0.07028   |
# 하이퍼파라미터: {'depth': 6, 'learning_rate': 0.05382066498104332, 'l2_leaf_reg': 9.96000172635551, 'bagging_temperature': 0.7940428281842834, 'border_count': 211, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7415092866554075
#
# | 21        | 0.7415    | 0.794     | 210.5     | 6.164     | 9.96      | 0.05382   |
# 하이퍼파라미터: {'depth': 8, 'learning_rate': 0.0878452009740168, 'l2_leaf_reg': 8.046718307997324, 'bagging_temperature': 0.5445767227640042, 'border_count': 246, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7414807771631712
#
# | 22        | 0.7415    | 0.5446    | 246.4     | 8.259     | 8.047     | 0.08785   |
# 하이퍼파라미터: {'depth': 6, 'learning_rate': 0.07770884549340276, 'l2_leaf_reg': 8.153777217107779, 'bagging_temperature': 0.7699651241615613, 'border_count': 241, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7419520272933005
#
# | 23        | 0.742     | 0.77      | 240.7     | 6.009     | 8.154     | 0.07771   |
# 하이퍼파라미터: {'depth': 6, 'learning_rate': 0.0511802799033821, 'l2_leaf_reg': 8.285500683774316, 'bagging_temperature': 0.7374039485112842, 'border_count': 238, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7418564280489655
#
# | 24        | 0.7419    | 0.7374    | 238.2     | 6.069     | 8.286     | 0.05118   |
# 하이퍼파라미터: {'depth': 6, 'learning_rate': 0.08412787156881296, 'l2_leaf_reg': 9.979624096919263, 'bagging_temperature': 0.5299896997395928, 'border_count': 240, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7402580377054989
#
# | 25        | 0.7403    | 0.53      | 240.4     | 6.082     | 9.98      | 0.08413   |
# 하이퍼파라미터: {'depth': 7, 'learning_rate': 0.08432811338502214, 'l2_leaf_reg': 8.004554826908745, 'bagging_temperature': 0.7856162468421598, 'border_count': 242, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7417642877312879
#
# | 26        | 0.7418    | 0.7856    | 241.8     | 6.696     | 8.005     | 0.08433   |
# 하이퍼파라미터: {'depth': 7, 'learning_rate': 0.07689746314594356, 'l2_leaf_reg': 8.02756448151241, 'bagging_temperature': 0.7596377277987246, 'border_count': 245, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7411585945314884
#
# | 27        | 0.7412    | 0.7596    | 244.9     | 6.503     | 8.028     | 0.0769    |
# 하이퍼파라미터: {'depth': 6, 'learning_rate': 0.08749344151162547, 'l2_leaf_reg': 9.79705399650108, 'bagging_temperature': 0.8452635866006784, 'border_count': 244, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7412045536374593
#
# | 28        | 0.7412    | 0.8453    | 243.8     | 6.266     | 9.797     | 0.08749   |
# 하이퍼파라미터: {'depth': 6, 'learning_rate': 0.08822703799600387, 'l2_leaf_reg': 9.33938139295918, 'bagging_temperature': 0.8957284341264546, 'border_count': 246, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7416075245158831
#
# | 29        | 0.7416    | 0.8957    | 246.5     | 6.469     | 9.339     | 0.08823   |
# 하이퍼파라미터: {'depth': 6, 'learning_rate': 0.08067079262266573, 'l2_leaf_reg': 8.069407808095985, 'bagging_temperature': 0.7006303175853194, 'border_count': 239, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7417572741257221
#
# | 30        | 0.7418    | 0.7006    | 239.4     | 6.048     | 8.069     | 0.08067   |
# 하이퍼파라미터: {'depth': 7, 'learning_rate': 0.09797373648401914, 'l2_leaf_reg': 8.022824562933817, 'bagging_temperature': 0.9561988825689712, 'border_count': 237, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7411020760252731
#
# | 31        | 0.7411    | 0.9562    | 237.2     | 6.861     | 8.023     | 0.09797   |
# 하이퍼파라미터: {'depth': 7, 'learning_rate': 0.07314376779212872, 'l2_leaf_reg': 8.360830470231202, 'bagging_temperature': 0.9210971924216698, 'border_count': 210, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7422365161137909
#
# | 32        | 0.7422    | 0.9211    | 210.4     | 6.74      | 8.361     | 0.07314   |
# 하이퍼파라미터: {'depth': 8, 'learning_rate': 0.09534588358538382, 'l2_leaf_reg': 8.400728790049842, 'bagging_temperature': 0.5477789733736456, 'border_count': 210, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7401055201646244
#
# | 33        | 0.7401    | 0.5478    | 210.3     | 7.58      | 8.401     | 0.09535   |
# 하이퍼파라미터: {'depth': 6, 'learning_rate': 0.050003925231028784, 'l2_leaf_reg': 9.897310081690748, 'bagging_temperature': 0.7086235657500897, 'border_count': 214, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7415289395580403
#
# | 34        | 0.7415    | 0.7086    | 214.2     | 6.182     | 9.897     | 0.05      |
# 하이퍼파라미터: {'depth': 7, 'learning_rate': 0.05523323111369133, 'l2_leaf_reg': 8.614088631974465, 'bagging_temperature': 0.5885900331404625, 'border_count': 225, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7416429340929758
#
# | 35        | 0.7416    | 0.5886    | 224.5     | 7.104     | 8.614     | 0.05523   |
# 하이퍼파라미터: {'depth': 9, 'learning_rate': 0.051083850396708284, 'l2_leaf_reg': 8.830185163852327, 'bagging_temperature': 0.6091580962291102, 'border_count': 246, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7415602643638692
#
# | 36        | 0.7416    | 0.6092    | 246.5     | 9.114     | 8.83      | 0.05108   |
# 하이퍼파라미터: {'depth': 10, 'learning_rate': 0.07979247546616036, 'l2_leaf_reg': 9.079279204485944, 'bagging_temperature': 0.6061250689904287, 'border_count': 240, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.74055635334839
#
# | 37        | 0.7406    | 0.6061    | 240.1     | 9.607     | 9.079     | 0.07979   |
# 하이퍼파라미터: {'depth': 9, 'learning_rate': 0.07273144435537499, 'l2_leaf_reg': 8.356034991369027, 'bagging_temperature': 0.5018188772815793, 'border_count': 226, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7408219839112133
#
# | 38        | 0.7408    | 0.5018    | 226.1     | 8.511     | 8.356     | 0.07273   |
# 하이퍼파라미터: {'depth': 7, 'learning_rate': 0.060098340471177944, 'l2_leaf_reg': 8.178675922652557, 'bagging_temperature': 0.7973899786544925, 'border_count': 204, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7418154914940314
#
# | 39        | 0.7418    | 0.7974    | 204.1     | 7.135     | 8.179     | 0.0601    |
# 하이퍼파라미터: {'depth': 8, 'learning_rate': 0.0942025978160874, 'l2_leaf_reg': 8.548084719395543, 'bagging_temperature': 0.8730964007381763, 'border_count': 212, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7411497497875237
#
# | 40        | 0.7411    | 0.8731    | 211.8     | 8.413     | 8.548     | 0.0942    |
# 하이퍼파라미터: {'depth': 8, 'learning_rate': 0.08479006666142967, 'l2_leaf_reg': 8.816749859969518, 'bagging_temperature': 0.7595990366090191, 'border_count': 253, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7414624480107234
#
# | 41        | 0.7415    | 0.7596    | 253.5     | 8.239     | 8.817     | 0.08479   |
# 하이퍼파라미터: {'depth': 7, 'learning_rate': 0.0629660213851071, 'l2_leaf_reg': 8.460214124186177, 'bagging_temperature': 0.6380884980963794, 'border_count': 234, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7418262187074982
#
# | 42        | 0.7418    | 0.6381    | 233.6     | 6.73      | 8.46      | 0.06297   |
# 하이퍼파라미터: {'depth': 7, 'learning_rate': 0.07097314929547394, 'l2_leaf_reg': 8.845532786404332, 'bagging_temperature': 0.802009837063935, 'border_count': 239, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7413711092479676
#
# | 43        | 0.7414    | 0.802     | 239.5     | 7.349     | 8.846     | 0.07097   |
# 하이퍼파라미터: {'depth': 9, 'learning_rate': 0.06110401547589591, 'l2_leaf_reg': 9.161778546989545, 'bagging_temperature': 0.8972012984707461, 'border_count': 247, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7412306179923297
#
# | 44        | 0.7412    | 0.8972    | 246.6     | 8.531     | 9.162     | 0.0611    |
# 하이퍼파라미터: {'depth': 9, 'learning_rate': 0.06033817836576674, 'l2_leaf_reg': 8.95825418298216, 'bagging_temperature': 0.5581983810686981, 'border_count': 225, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7411736148020422
#
# | 45        | 0.7412    | 0.5582    | 224.6     | 8.85      | 8.958     | 0.06034   |
# 하이퍼파라미터: {'depth': 9, 'learning_rate': 0.05438314745873113, 'l2_leaf_reg': 8.989097953788484, 'bagging_temperature': 0.9337020709064412, 'border_count': 204, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7413899211102144
#
# | 46        | 0.7414    | 0.9337    | 203.8     | 8.646     | 8.989     | 0.05438   |
# 하이퍼파라미터: {'depth': 8, 'learning_rate': 0.07118718386671719, 'l2_leaf_reg': 8.601686099422157, 'bagging_temperature': 0.9212560936756672, 'border_count': 217, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7414137723048204
#
# | 47        | 0.7414    | 0.9213    | 217.3     | 7.548     | 8.602     | 0.07119   |
# 하이퍼파라미터: {'depth': 10, 'learning_rate': 0.05756005423931219, 'l2_leaf_reg': 9.885932121244114, 'bagging_temperature': 0.8418232774971094, 'border_count': 251, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7412477191468432
#
# | 48        | 0.7412    | 0.8418    | 251.3     | 9.577     | 9.886     | 0.05756   |
# 하이퍼파라미터: {'depth': 9, 'learning_rate': 0.05575676712355734, 'l2_leaf_reg': 9.18074577500753, 'bagging_temperature': 0.9002171181423197, 'border_count': 226, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7411576360218467
#
# | 49        | 0.7412    | 0.9002    | 225.9     | 9.439     | 9.181     | 0.05576   |
# 하이퍼파라미터: {'depth': 8, 'learning_rate': 0.05548594635191602, 'l2_leaf_reg': 8.768709431328132, 'bagging_temperature': 0.6300952217877054, 'border_count': 242, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7412215086957554
#
# | 50        | 0.7412    | 0.6301    | 242.2     | 8.219     | 8.769     | 0.05549   |
# 하이퍼파라미터: {'depth': 7, 'learning_rate': 0.08714254853150455, 'l2_leaf_reg': 9.514877071259281, 'bagging_temperature': 0.643483512103018, 'border_count': 244, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7412277720775026
#
# | 51        | 0.7412    | 0.6435    | 244.0     | 7.277     | 9.515     | 0.08714   |
# 하이퍼파라미터: {'depth': 7, 'learning_rate': 0.08533278166705394, 'l2_leaf_reg': 8.485067345659111, 'bagging_temperature': 0.6684276756839906, 'border_count': 210, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7410073938308424
#
# | 52        | 0.741     | 0.6684    | 210.3     | 6.617     | 8.485     | 0.08533   |
# 하이퍼파라미터: {'depth': 8, 'learning_rate': 0.0789698369600173, 'l2_leaf_reg': 8.7360803559834, 'bagging_temperature': 0.685012477372118, 'border_count': 229, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7415693183807935
#
# | 53        | 0.7416    | 0.685     | 228.6     | 8.374     | 8.736     | 0.07897   |
# 하이퍼파라미터: {'depth': 8, 'learning_rate': 0.06427805909477041, 'l2_leaf_reg': 8.891126955034897, 'bagging_temperature': 0.6717657220782461, 'border_count': 209, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7411894395889279
#
# | 54        | 0.7412    | 0.6718    | 209.0     | 7.778     | 8.891     | 0.06428   |
# 하이퍼파라미터: {'depth': 9, 'learning_rate': 0.08881568899722493, 'l2_leaf_reg': 8.265616452112667, 'bagging_temperature': 0.7181569510156239, 'border_count': 201, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7413674134085252
#
# | 55        | 0.7414    | 0.7182    | 200.9     | 9.14      | 8.266     | 0.08882   |
# 하이퍼파라미터: {'depth': 7, 'learning_rate': 0.061951117038655364, 'l2_leaf_reg': 9.92452935118528, 'bagging_temperature': 0.8558168400525119, 'border_count': 237, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7410227763805297
#
# | 56        | 0.741     | 0.8558    | 237.5     | 6.702     | 9.925     | 0.06195   |
# 하이퍼파라미터: {'depth': 8, 'learning_rate': 0.07063314252780582, 'l2_leaf_reg': 8.981128825703795, 'bagging_temperature': 0.920389634304227, 'border_count': 207, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7412012526526583
#
# | 57        | 0.7412    | 0.9204    | 206.9     | 8.166     | 8.981     | 0.07063   |
# 하이퍼파라미터: {'depth': 8, 'learning_rate': 0.08096089098150738, 'l2_leaf_reg': 8.733154185740153, 'bagging_temperature': 0.7586253794649289, 'border_count': 206, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7415147010996761
#
# | 58        | 0.7415    | 0.7586    | 206.1     | 8.267     | 8.733     | 0.08096   |
# 하이퍼파라미터: {'depth': 7, 'learning_rate': 0.09530898844526581, 'l2_leaf_reg': 9.362564399451664, 'bagging_temperature': 0.7007046101477041, 'border_count': 239, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7415007972806203
#
# | 59        | 0.7415    | 0.7007    | 239.2     | 7.167     | 9.363     | 0.09531   |
# 하이퍼파라미터: {'depth': 8, 'learning_rate': 0.08295379410429032, 'l2_leaf_reg': 8.476881073769183, 'bagging_temperature': 0.6726489532149644, 'border_count': 215, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7410332538484359
#
# | 60        | 0.741     | 0.6726    | 215.2     | 8.026     | 8.477     | 0.08295   |
# 하이퍼파라미터: {'depth': 9, 'learning_rate': 0.0681690252292873, 'l2_leaf_reg': 8.83785458373944, 'bagging_temperature': 0.9131082741795193, 'border_count': 227, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7409801607062338
#
# | 61        | 0.741     | 0.9131    | 226.8     | 8.939     | 8.838     | 0.06817   |
# 하이퍼파라미터: {'depth': 10, 'learning_rate': 0.07234338021822027, 'l2_leaf_reg': 9.947436234385455, 'bagging_temperature': 0.5274972970734237, 'border_count': 218, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7413568609182373
#
# | 62        | 0.7414    | 0.5275    | 217.6     | 9.578     | 9.947     | 0.07234   |
# 하이퍼파라미터: {'depth': 9, 'learning_rate': 0.07809907661703168, 'l2_leaf_reg': 8.960081357387324, 'bagging_temperature': 0.783850383238593, 'border_count': 221, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7412838759863443
#
# | 63        | 0.7413    | 0.7839    | 220.8     | 9.032     | 8.96      | 0.0781    |
# 하이퍼파라미터: {'depth': 7, 'learning_rate': 0.08796292998090247, 'l2_leaf_reg': 9.931274981598168, 'bagging_temperature': 0.6007662913573536, 'border_count': 242, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7410614701611014
#
# | 64        | 0.7411    | 0.6008    | 242.1     | 6.898     | 9.931     | 0.08796   |
# 하이퍼파라미터: {'depth': 7, 'learning_rate': 0.060968707349960446, 'l2_leaf_reg': 9.72363713401164, 'bagging_temperature': 0.5513210157090522, 'border_count': 243, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7416273402960554
#
# | 65        | 0.7416    | 0.5513    | 243.2     | 6.626     | 9.724     | 0.06097   |
# 하이퍼파라미터: {'depth': 10, 'learning_rate': 0.0733454610068721, 'l2_leaf_reg': 8.022963379871694, 'bagging_temperature': 0.5005248528607265, 'border_count': 214, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7406349027693151
#
# | 66        | 0.7406    | 0.5005    | 213.7     | 9.976     | 8.023     | 0.07335   |
# 하이퍼파라미터: {'depth': 7, 'learning_rate': 0.06550120981953311, 'l2_leaf_reg': 9.196044503263687, 'bagging_temperature': 0.5507561104432016, 'border_count': 202, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7415049916240473
#
# | 67        | 0.7415    | 0.5508    | 201.6     | 7.101     | 9.196     | 0.0655    |
# 하이퍼파라미터: {'depth': 6, 'learning_rate': 0.09055965311027547, 'l2_leaf_reg': 8.813414895788283, 'bagging_temperature': 0.9983949696258068, 'border_count': 225, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7410804616822099
#
# | 68        | 0.7411    | 0.9984    | 224.7     | 6.055     | 8.813     | 0.09056   |
# 하이퍼파라미터: {'depth': 8, 'learning_rate': 0.0832528431465238, 'l2_leaf_reg': 8.594945956172444, 'bagging_temperature': 0.6113131642036326, 'border_count': 217, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7413579852668283
#
# | 69        | 0.7414    | 0.6113    | 217.3     | 7.835     | 8.595     | 0.08325   |
# 하이퍼파라미터: {'depth': 9, 'learning_rate': 0.06932887135543564, 'l2_leaf_reg': 9.605644515500002, 'bagging_temperature': 0.6325386485693663, 'border_count': 250, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7411715052911212
#
# | 70        | 0.7412    | 0.6325    | 250.3     | 8.642     | 9.606     | 0.06933   |
# 하이퍼파라미터: {'depth': 10, 'learning_rate': 0.08062649462076504, 'l2_leaf_reg': 8.52167415993934, 'bagging_temperature': 0.8877506549415686, 'border_count': 237, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7407904330511024
#
# | 71        | 0.7408    | 0.8878    | 236.6     | 9.803     | 8.522     | 0.08063   |
# 하이퍼파라미터: {'depth': 7, 'learning_rate': 0.07316776988277597, 'l2_leaf_reg': 8.995990297884358, 'bagging_temperature': 0.8664231279176409, 'border_count': 219, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7413386926690557
#
# | 72        | 0.7413    | 0.8664    | 219.5     | 6.942     | 8.996     | 0.07317   |
# 하이퍼파라미터: {'depth': 7, 'learning_rate': 0.08644987256961029, 'l2_leaf_reg': 8.380704935776013, 'bagging_temperature': 0.6192915078755353, 'border_count': 234, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7416253512157999
#
# | 73        | 0.7416    | 0.6193    | 233.6     | 6.987     | 8.381     | 0.08645   |
# 하이퍼파라미터: {'depth': 6, 'learning_rate': 0.09745846313532845, 'l2_leaf_reg': 8.260266670219082, 'bagging_temperature': 0.9497427562332559, 'border_count': 243, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7418036705332083
#
# | 74        | 0.7418    | 0.9497    | 243.3     | 6.139     | 8.26      | 0.09746   |
# 하이퍼파라미터: {'depth': 7, 'learning_rate': 0.08300055201931272, 'l2_leaf_reg': 8.507534655755663, 'bagging_temperature': 0.7884887520419241, 'border_count': 211, 'loss_function': 'Logloss', 'eval_metric': 'AUC', 'iterations': 2500, 'random_seed': 1991, 'verbose': 200}
# ROC-AUC : 0.7415545142931556
#
# | 75        | 0.7416    | 0.7885    | 210.7     | 6.923     | 8.508     | 0.083     |
# =====================================================================================

# %%
max_params = optimizer.max['params']
max_params['depth'] = int(round(max_params['depth']))
max_params['border_count'] = int(round(max_params['border_count']))
max_params.update(fixed_params)

# %%
max_params
# Out:
# {'bagging_temperature': 0.9210971924216698,
#  'border_count': 210,
#  'depth': 7,
#  'l2_leaf_reg': 8.360830470231202,
#  'learning_rate': 0.07314376779212872,
#  'loss_function': 'Logloss',
#  'eval_metric': 'AUC',
#  'iterations': 2500,
#  'random_seed': 1991,
#  'verbose': 200}

# %% [markdown]
# ## 6. 모델 훈련

# %%
from sklearn.model_selection import StratifiedKFold

# 층화 K 폴드 교차 검증기
folds = StratifiedKFold(n_splits=10, shuffle=True, random_state=1991)

# %%
# OOF 방식으로 훈련된 모델로 검증 데이터 타깃값을 예측한 확률을 담을 1차원 배열
oof_val_preds = np.zeros(X.shape[0]) 
# OOF 방식으로 훈련된 모델로 테스트 데이터 타깃값을 예측한 확률을 담을 1차원 배열
oof_test_preds = np.zeros(X_test.shape[0])

# %%
from sklearn.metrics import roc_auc_score

for idx, (train_idx, valid_idx) in enumerate(folds.split(X, y)):
    print('#'*40, f'폴드 {idx+1} / 폴드 {folds.n_splits}', '#'*40)
    
    X_train, y_train = X[train_idx], y[train_idx]
    X_valid, y_valid = X[valid_idx], y[valid_idx]
    
    dtrain = Pool(X_train, y_train, cat_features=None)
    dvalid = Pool(X_valid, y_valid, cat_features=None)
    
    cat_model = CatBoostClassifier(**max_params)
    cat_model.fit(dtrain, eval_set=dvalid, early_stopping_rounds=200, verbose=500)
    
    # 테스트 데이터 예측
    oof_test_preds += cat_model.predict_proba(X_test)[:, 1] / folds.n_splits
    # 검증 데이터 예측
    oof_val_preds[valid_idx] += cat_model.predict_proba(X_valid)[:, 1]
    
    # 검증 데이터 ROC-AUC 계산
    roc_auc = roc_auc_score(y_valid, oof_val_preds[valid_idx])
    print(f'폴드 {idx+1} ROC-AUC : {roc_auc}\n')

# %% [markdown]
# ## 7. 최종 결과

# %%
print('최종 OOF 검증 데이터 ROC-AUC:', roc_auc_score(y, oof_val_preds))

# %%
submission['probability'] = oof_test_preds
submission.to_csv('cat_onehot_submission.csv')
