# %% [markdown]
# # LGBM + CatBoost 앙상블

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/lg-aimers/sample_submission.csv
# /kaggle/input/lg-aimers/train.csv
# /kaggle/input/lg-aimers/test.csv

# %%
data_path = '/kaggle/input/lg-aimers/'

train = pd.read_csv(data_path + 'train.csv', index_col= 'ID')
test = pd.read_csv(data_path + 'test.csv', index_col= 'ID')
submission = pd.read_csv(data_path + 'sample_submission.csv', index_col= 'ID')

# %% [markdown]
# ## 1. 데이터 통합

# %%
all_data = pd.concat([train, test], ignore_index= True)
all_data = all_data.drop('임신 성공 여부', axis= 1)

# %%
categorical_columns = [
    "시술 시기 코드",
    "시술 당시 나이",
    "시술 유형",
    "특정 시술 유형",
    "배란 자극 여부",
    "배란 유도 유형",
    "단일 배아 이식 여부",
    "착상 전 유전 검사 사용 여부",
    "착상 전 유전 진단 사용 여부",
    "남성 주 불임 원인",
    "남성 부 불임 원인",
    "여성 주 불임 원인",
    "여성 부 불임 원인",
    "부부 주 불임 원인",
    "부부 부 불임 원인",
    "불명확 불임 원인",
    "불임 원인 - 난관 질환",
    "불임 원인 - 남성 요인",
    "불임 원인 - 배란 장애",
    "불임 원인 - 여성 요인",
    "불임 원인 - 자궁경부 문제",
    "불임 원인 - 자궁내막증",
    "불임 원인 - 정자 농도",
    "불임 원인 - 정자 면역학적 요인",
    "불임 원인 - 정자 운동성",
    "불임 원인 - 정자 형태",
    "배아 생성 주요 이유",
    "총 시술 횟수",
    "클리닉 내 총 시술 횟수",
    "IVF 시술 횟수",
    "DI 시술 횟수",
    "총 임신 횟수",
    "IVF 임신 횟수",
    "DI 임신 횟수",
    "총 출산 횟수",
    "IVF 출산 횟수",
    "DI 출산 횟수",
    "난자 출처",
    "정자 출처",
    "난자 기증자 나이",
    "정자 기증자 나이",
    "동결 배아 사용 여부",
    "신선 배아 사용 여부",
    "기증 배아 사용 여부",
    "대리모 여부",
    "PGD 시술 여부",
    "PGS 시술 여부"
]

# %%
# 카테고리형 컬럼들을 문자열로 변환
for col in categorical_columns:
    all_data[col] = all_data[col].astype(str)

# %% [markdown]
# ## 2. 피처 엔지니어링: 원 핫 인코딩

# %%
from sklearn.preprocessing import OneHotEncoder

onehot_encoder = OneHotEncoder()

encoded_cat_matrix = onehot_encoder.fit_transform(all_data[categorical_columns])

encoded_cat_matrix
# Out:
# <346418x205 sparse matrix of type '<class 'numpy.float64'>'
# 	with 16281646 stored elements in Compressed Sparse Row format>

# %%
all_columns = all_data.columns
all_columns
# Out:
# Index(['시술 시기 코드', '시술 당시 나이', '임신 시도 또는 마지막 임신 경과 연수', '시술 유형', '특정 시술 유형',
#        '배란 자극 여부', '배란 유도 유형', '단일 배아 이식 여부', '착상 전 유전 검사 사용 여부',
#        '착상 전 유전 진단 사용 여부', '남성 주 불임 원인', '남성 부 불임 원인', '여성 주 불임 원인',
#        '여성 부 불임 원인', '부부 주 불임 원인', '부부 부 불임 원인', '불명확 불임 원인', '불임 원인 - 난관 질환',
#        '불임 원인 - 남성 요인', '불임 원인 - 배란 장애', '불임 원인 - 여성 요인', '불임 원인 - 자궁경부 문제',
#        '불임 원인 - 자궁내막증', '불임 원인 - 정자 농도', '불임 원인 - 정자 면역학적 요인',
#        '불임 원인 - 정자 운동성', '불임 원인 - 정자 형태', '배아 생성 주요 이유', '총 시술 횟수',
#        '클리닉 내 총 시술 횟수', 'IVF 시술 횟수', 'DI 시술 횟수', '총 임신 횟수', 'IVF 임신 횟수',
#        'DI 임신 횟수', '총 출산 횟수', 'IVF 출산 횟수', 'DI 출산 횟수', '총 생성 배아 수',
#        '미세주입된 난자 수', '미세주입에서 생성된 배아 수', '이식된 배아 수', '미세주입 배아 이식 수', '저장된 배아 수',
#        '미세주입 후 저장된 배아 수', '해동된 배아 수', '해동 난자 수', '수집된 신선 난자 수', '저장된 신선 난자 수',
#        '혼합된 난자 수', '파트너 정자와 혼합된 난자 수', '기증자 정자와 혼합된 난자 수', '난자 출처', '정자 출처',
#        '난자 기증자 나이', '정자 기증자 나이', '동결 배아 사용 여부', '신선 배아 사용 여부', '기증 배아 사용 여부',
#        '대리모 여부', 'PGD 시술 여부', 'PGS 시술 여부', '난자 채취 경과일', '난자 해동 경과일',
#        '난자 혼합 경과일', '배아 이식 경과일', '배아 해동 경과일'],
#       dtype='object')

# %%
remaining_columns = list(set(all_columns) - set(categorical_columns))

# %%
from scipy import sparse

extracted_data_sprs = sparse.hstack([sparse.csr_matrix(all_data[remaining_columns]),
                               encoded_cat_matrix],
                              format='csr')

# %% [markdown]
# ## 3. 데이터 나누기

# %%
num_train = len(train) 

X = extracted_data_sprs[:num_train]
X_test = extracted_data_sprs[num_train:]

y = train['임신 성공 여부'].values

# %% [markdown]
# ## 4. ROC-AUC 정의

# %%
from sklearn.metrics import roc_auc_score

# LGBM 커스텀 평가 함수
def lgb_roc_auc(y_pred, dataset):
    y_true = dataset.get_label()
    return "roc_auc", roc_auc_score(y_true, y_pred), True  # (지표 이름, 값, 높은 값이 더 좋은지 여부)

# %%
# XGBoost 커스텀 평가 함수
def xgb_roc_auc(y_pred, dtrain):
    y_true = dtrain.get_label()
    return "roc_auc", roc_auc_score(y_true, y_pred)

# %% [markdown]
# ## 5. 층화 K 폴드 설정

# %%
from sklearn.model_selection import StratifiedKFold

# 층화 K 폴드 교차 검증기 생성
folds = StratifiedKFold(n_splits=10, shuffle=True, random_state=1991)

# %% [markdown]
# ## 6. 모델 훈련

# %% [markdown]
# ### 6-1. LGBM

# %%
max_params_lgb = {
    'bagging_fraction': 0.5024417571224058,
    'feature_fraction': 0.8828297423537881,
    'lambda_l1': 0.12365931116742002,
    'lambda_l2': 1.8847998821750824,
    'min_child_samples': 6,
    'min_child_weight': 33.74412877738659,
    'num_leaves': 32,
    'objective': 'binary',
    'learning_rate': 0.005,
    'bagging_freq': 1,
    'force_row_wise': True,
    'random_state': 1991
}

# %%
import lightgbm as lgb

# OOF 방식으로 훈련된 모델로 검증 데이터 타깃값을 예측한 확률을 담을 1차원 배열
oof_val_preds_lgb = np.zeros(X.shape[0]) 
# OOF 방식으로 훈련된 모델로 테스트 데이터 타깃값을 예측한 확률을 담을 1차원 배열
oof_test_preds_lgb = np.zeros(X_test.shape[0]) 

# OOF 방식으로 모델 훈련, 검증, 예측
for idx, (train_idx, valid_idx) in enumerate(folds.split(X, y)):
    # 각 폴드를 구분하는 문구 출력
    print('#'*40, f'폴드 {idx+1} / 폴드 {folds.n_splits}', '#'*40)
    
    # 훈련용 데이터, 검증용 데이터 설정
    X_train, y_train = X[train_idx], y[train_idx] # 훈련용 데이터
    X_valid, y_valid = X[valid_idx], y[valid_idx] # 검증용 데이터

    # LightGBM 전용 데이터셋 생성
    dtrain = lgb.Dataset(X_train, y_train) # LightGBM 전용 훈련 데이터셋
    dvalid = lgb.Dataset(X_valid, y_valid) # LightGBM 전용 검증 데이터셋
                          
    # LightGBM 모델 훈련
    lgb_model = lgb.train(params=max_params_lgb,     # 최적 하이퍼파라미터
                          train_set=dtrain,          # 훈련 데이터셋
                          num_boost_round=2500,      # 부스팅 반복 횟수
                          valid_sets=dvalid,         # 성능 평가용 검증 데이터셋
                          feval = lgb_roc_auc,
                          callbacks=[lgb.early_stopping(stopping_rounds=100)])
    
    # 테스트 데이터를 활용해 OOF 예측
    oof_test_preds_lgb += lgb_model.predict(X_test)/folds.n_splits
    
    # 모델 성능 평가를 위한 검증 데이터 타깃값 예측 
    oof_val_preds_lgb[valid_idx] += lgb_model.predict(X_valid)
    
    # 검증 데이터 예측 확률에 대한 ROC-AUC
    roc_auc = roc_auc_score(y_valid, oof_val_preds_lgb[valid_idx])
    print(f'폴드 {idx+1} roc-auc : {roc_auc}\n')
# Out:
# ######################################## 폴드 1 / 폴드 10 ########################################
# [LightGBM] [Info] Number of positive: 59605, number of negative: 171110
# [LightGBM] [Info] Total Bins 907
# [LightGBM] [Info] Number of data points in the train set: 230715, number of used features: 199
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258349 -> initscore=-1.054567
# [LightGBM] [Info] Start training from score -1.054567
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1816]	valid_0's binary_logloss: 0.4878	valid_0's roc_auc: 0.740013
# 폴드 1 roc-auc : 0.7400134188247701
#
# ######################################## 폴드 2 / 폴드 10 ########################################
# [LightGBM] [Info] Number of positive: 59606, number of negative: 171110
# [LightGBM] [Info] Total Bins 906
# [LightGBM] [Info] Number of data points in the train set: 230716, number of used features: 198
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258352 -> initscore=-1.054550
# [LightGBM] [Info] Start training from score -1.054550
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [2012]	valid_0's binary_logloss: 0.487057	valid_0's roc_auc: 0.739716
# 폴드 2 roc-auc : 0.7397163186586335
#
# ######################################## 폴드 3 / 폴드 10 ########################################
# [LightGBM] [Info] Number of positive: 59606, number of negative: 171110
# [LightGBM] [Info] Total Bins 912
# [LightGBM] [Info] Number of data points in the train set: 230716, number of used features: 198
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258352 -> initscore=-1.054550
# [LightGBM] [Info] Start training from score -1.054550
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [2473]	valid_0's binary_logloss: 0.489677	valid_0's roc_auc: 0.735174
# 폴드 3 roc-auc : 0.7351739482068913
#
# ######################################## 폴드 4 / 폴드 10 ########################################
# [LightGBM] [Info] Number of positive: 59605, number of negative: 171111
# [LightGBM] [Info] Total Bins 910
# [LightGBM] [Info] Number of data points in the train set: 230716, number of used features: 201
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258348 -> initscore=-1.054573
# [LightGBM] [Info] Start training from score -1.054573
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1830]	valid_0's binary_logloss: 0.488305	valid_0's roc_auc: 0.739342
# 폴드 4 roc-auc : 0.7393416807503411
#
# ######################################## 폴드 5 / 폴드 10 ########################################
# [LightGBM] [Info] Number of positive: 59605, number of negative: 171111
# [LightGBM] [Info] Total Bins 915
# [LightGBM] [Info] Number of data points in the train set: 230716, number of used features: 200
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258348 -> initscore=-1.054573
# [LightGBM] [Info] Start training from score -1.054573
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1553]	valid_0's binary_logloss: 0.486978	valid_0's roc_auc: 0.742101
# 폴드 5 roc-auc : 0.742101462559991
#
# ######################################## 폴드 6 / 폴드 10 ########################################
# [LightGBM] [Info] Number of positive: 59605, number of negative: 171111
# [LightGBM] [Info] Total Bins 914
# [LightGBM] [Info] Number of data points in the train set: 230716, number of used features: 200
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258348 -> initscore=-1.054573
# [LightGBM] [Info] Start training from score -1.054573
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1959]	valid_0's binary_logloss: 0.489161	valid_0's roc_auc: 0.736499
# 폴드 6 roc-auc : 0.7364992528856986
#
# ######################################## 폴드 7 / 폴드 10 ########################################
# [LightGBM] [Info] Number of positive: 59605, number of negative: 171111
# [LightGBM] [Info] Total Bins 916
# [LightGBM] [Info] Number of data points in the train set: 230716, number of used features: 201
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258348 -> initscore=-1.054573
# [LightGBM] [Info] Start training from score -1.054573
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1724]	valid_0's binary_logloss: 0.486428	valid_0's roc_auc: 0.744187
# 폴드 7 roc-auc : 0.7441873611520068
#
# ######################################## 폴드 8 / 폴드 10 ########################################
# [LightGBM] [Info] Number of positive: 59605, number of negative: 171111
# [LightGBM] [Info] Total Bins 916
# [LightGBM] [Info] Number of data points in the train set: 230716, number of used features: 201
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258348 -> initscore=-1.054573
# [LightGBM] [Info] Start training from score -1.054573
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1456]	valid_0's binary_logloss: 0.488127	valid_0's roc_auc: 0.740479
# 폴드 8 roc-auc : 0.7404794349549617
#
# ######################################## 폴드 9 / 폴드 10 ########################################
# [LightGBM] [Info] Number of positive: 59605, number of negative: 171111
# [LightGBM] [Info] Total Bins 914
# [LightGBM] [Info] Number of data points in the train set: 230716, number of used features: 202
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258348 -> initscore=-1.054573
# [LightGBM] [Info] Start training from score -1.054573
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1465]	valid_0's binary_logloss: 0.484945	valid_0's roc_auc: 0.745591
# 폴드 9 roc-auc : 0.7455907120526467
#
# ######################################## 폴드 10 / 폴드 10 ########################################
# [LightGBM] [Info] Number of positive: 59605, number of negative: 171111
# [LightGBM] [Info] Total Bins 917
# [LightGBM] [Info] Number of data points in the train set: 230716, number of used features: 200
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.258348 -> initscore=-1.054573
# [LightGBM] [Info] Start training from score -1.054573
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [1923]	valid_0's binary_logloss: 0.487699	valid_0's roc_auc: 0.741455
# 폴드 10 roc-auc : 0.7414552961282047

# %% [markdown]
# ### 6-2. CatBoost

# %%
max_params_catboost = {
	'bagging_temperature': 0.8125525342743981,
	'border_count': 150,
	'depth': 7,
	'l2_leaf_reg': 9.330369744633948,
	'learning_rate': 0.016393245237809825,
	'loss_function': 'Logloss',
	'eval_metric': 'AUC',
	'iterations': 2500,
	'random_seed': 1991,
	'verbose': 200
}

# %%
from sklearn.metrics import roc_auc_score
from catboost import CatBoostClassifier, Pool

# OOF 방식으로 모델 훈련, 검증, 예측
oof_val_preds_catboost = np.zeros(X.shape[0])
oof_test_preds_catboost = np.zeros(X_test.shape[0])

for idx, (train_idx, valid_idx) in enumerate(folds.split(X, y)):
    print('#'*40, f'폴드 {idx+1} / 폴드 {folds.n_splits}', '#'*40)
    
    X_train, y_train = X[train_idx], y[train_idx]
    X_valid, y_valid = X[valid_idx], y[valid_idx]
    
    dtrain = Pool(X_train, y_train, cat_features=None)
    dvalid = Pool(X_valid, y_valid, cat_features=None)
    
    cat_model = CatBoostClassifier(**max_params_catboost)
    cat_model.fit(dtrain, 
                  eval_set=dvalid, 
                  early_stopping_rounds=200, 
                  verbose=500)
    
    # 테스트 데이터 예측
    oof_test_preds_catboost += cat_model.predict_proba(X_test)[:, 1] / folds.n_splits
    # 검증 데이터 예측
    oof_val_preds_catboost[valid_idx] += cat_model.predict_proba(X_valid)[:, 1]
    
    # 검증 데이터 ROC-AUC 계산
    roc_auc = roc_auc_score(y_valid, oof_val_preds_catboost[valid_idx])
    print(f'폴드 {idx+1} ROC-AUC : {roc_auc}\n')
# Out:
# ######################################## 폴드 1 / 폴드 10 ########################################
# 0:	test: 0.7098001	best: 0.7098001 (0)	total: 43.2ms	remaining: 1m 47s
# 500:	test: 0.7376283	best: 0.7376283 (500)	total: 20.1s	remaining: 1m 20s
# 1000:	test: 0.7391794	best: 0.7391839 (997)	total: 39.1s	remaining: 58.6s
# 1500:	test: 0.7396886	best: 0.7397079 (1492)	total: 57.5s	remaining: 38.3s
# 2000:	test: 0.7398318	best: 0.7398794 (1821)	total: 1m 16s	remaining: 19s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7398794243
# bestIteration = 1821
#
# Shrink model to first 1822 iterations.
# 폴드 1 ROC-AUC : 0.7397970566146883
#
# ######################################## 폴드 2 / 폴드 10 ########################################
# 0:	test: 0.6964769	best: 0.6964769 (0)	total: 39.8ms	remaining: 1m 39s
# 500:	test: 0.7361486	best: 0.7361486 (500)	total: 20.5s	remaining: 1m 21s
# 1000:	test: 0.7376043	best: 0.7376509 (923)	total: 38.7s	remaining: 58s
# 1500:	test: 0.7378968	best: 0.7379208 (1486)	total: 57.5s	remaining: 38.3s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7379208209
# bestIteration = 1486
#
# Shrink model to first 1487 iterations.
# 폴드 2 ROC-AUC : 0.7389500409065358
#
# ######################################## 폴드 3 / 폴드 10 ########################################
# 0:	test: 0.7051967	best: 0.7051967 (0)	total: 43.4ms	remaining: 1m 48s
# 500:	test: 0.7307592	best: 0.7307592 (500)	total: 20.5s	remaining: 1m 21s
# 1000:	test: 0.7325431	best: 0.7325513 (997)	total: 39s	remaining: 58.3s
# 1500:	test: 0.7331042	best: 0.7331078 (1494)	total: 57.8s	remaining: 38.5s
# 2000:	test: 0.7333911	best: 0.7333911 (2000)	total: 1m 16s	remaining: 19s
# 2499:	test: 0.7336156	best: 0.7336245 (2484)	total: 1m 34s	remaining: 0us
#
# bestTest = 0.7336245307
# bestIteration = 2484
#
# Shrink model to first 2485 iterations.
# 폴드 3 ROC-AUC : 0.7342010409415942
#
# ######################################## 폴드 4 / 폴드 10 ########################################
# 0:	test: 0.6867309	best: 0.6867309 (0)	total: 38.1ms	remaining: 1m 35s
# 500:	test: 0.7357199	best: 0.7357199 (500)	total: 20.7s	remaining: 1m 22s
# 1000:	test: 0.7371993	best: 0.7372055 (993)	total: 39.3s	remaining: 58.8s
# 1500:	test: 0.7379508	best: 0.7379573 (1488)	total: 58.4s	remaining: 38.9s
# 2000:	test: 0.7383675	best: 0.7383888 (1978)	total: 1m 16s	remaining: 19.2s
# 2499:	test: 0.7385184	best: 0.7385184 (2499)	total: 1m 35s	remaining: 0us
#
# bestTest = 0.738518389
# bestIteration = 2499
#
# 폴드 4 ROC-AUC : 0.7391797797771914
#
# ######################################## 폴드 5 / 폴드 10 ########################################
# 0:	test: 0.7076156	best: 0.7076156 (0)	total: 39.6ms	remaining: 1m 39s
# 500:	test: 0.7407186	best: 0.7407186 (500)	total: 20.5s	remaining: 1m 21s
# 1000:	test: 0.7415836	best: 0.7415836 (1000)	total: 39s	remaining: 58.4s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7417291205
# bestIteration = 1269
#
# Shrink model to first 1270 iterations.
# 폴드 5 ROC-AUC : 0.7410864881574353
#
# ######################################## 폴드 6 / 폴드 10 ########################################
# 0:	test: 0.7043613	best: 0.7043613 (0)	total: 41ms	remaining: 1m 42s
# 500:	test: 0.7338738	best: 0.7338755 (495)	total: 20.6s	remaining: 1m 22s
# 1000:	test: 0.7350536	best: 0.7350536 (999)	total: 39s	remaining: 58.4s
# 1500:	test: 0.7353717	best: 0.7353717 (1500)	total: 57.7s	remaining: 38.4s
# 2000:	test: 0.7355708	best: 0.7355733 (1975)	total: 1m 15s	remaining: 18.9s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7357158248
# bestIteration = 2148
#
# Shrink model to first 2149 iterations.
# 폴드 6 ROC-AUC : 0.7353238030581478
#
# ######################################## 폴드 7 / 폴드 10 ########################################
# 0:	test: 0.7119261	best: 0.7119261 (0)	total: 43.9ms	remaining: 1m 49s
# 500:	test: 0.7408640	best: 0.7408640 (500)	total: 20.1s	remaining: 1m 20s
# 1000:	test: 0.7426013	best: 0.7426019 (999)	total: 39.4s	remaining: 59s
# 1500:	test: 0.7432012	best: 0.7432028 (1493)	total: 57.7s	remaining: 38.4s
# 2000:	test: 0.7433641	best: 0.7433859 (1890)	total: 1m 16s	remaining: 19s
# 2499:	test: 0.7433897	best: 0.7434500 (2339)	total: 1m 34s	remaining: 0us
#
# bestTest = 0.7434500152
# bestIteration = 2339
#
# Shrink model to first 2340 iterations.
# 폴드 7 ROC-AUC : 0.7441476205226708
#
# ######################################## 폴드 8 / 폴드 10 ########################################
# 0:	test: 0.7069466	best: 0.7069466 (0)	total: 37.5ms	remaining: 1m 33s
# 500:	test: 0.7394894	best: 0.7394894 (500)	total: 20.1s	remaining: 1m 20s
# 1000:	test: 0.7402270	best: 0.7402270 (1000)	total: 39.2s	remaining: 58.7s
# 1500:	test: 0.7403498	best: 0.7403803 (1418)	total: 57.4s	remaining: 38.2s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7403964355
# bestIteration = 1627
#
# Shrink model to first 1628 iterations.
# 폴드 8 ROC-AUC : 0.7403123003537679
#
# ######################################## 폴드 9 / 폴드 10 ########################################
# 0:	test: 0.7170216	best: 0.7170216 (0)	total: 39.7ms	remaining: 1m 39s
# 500:	test: 0.7439116	best: 0.7439116 (500)	total: 20.5s	remaining: 1m 21s
# 1000:	test: 0.7448024	best: 0.7448100 (984)	total: 38.9s	remaining: 58.2s
# 1500:	test: 0.7448550	best: 0.7449105 (1346)	total: 57.6s	remaining: 38.4s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7449104913
# bestIteration = 1346
#
# Shrink model to first 1347 iterations.
# 폴드 9 ROC-AUC : 0.7446804340362894
#
# ######################################## 폴드 10 / 폴드 10 ########################################
# 0:	test: 0.7176076	best: 0.7176076 (0)	total: 42.3ms	remaining: 1m 45s
# 500:	test: 0.7389630	best: 0.7389630 (500)	total: 20.1s	remaining: 1m 20s
# 1000:	test: 0.7401580	best: 0.7401640 (998)	total: 39.3s	remaining: 58.8s
# 1500:	test: 0.7404847	best: 0.7404847 (1500)	total: 58s	remaining: 38.6s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.7405069055
# bestIteration = 1701
#
# Shrink model to first 1702 iterations.
# 폴드 10 ROC-AUC : 0.7402945346087989

# %% [markdown]
# ## 5. 최종 결과

# %%
print('LightGBM OOF 검증 데이터 ROC-AUC :', roc_auc_score(y, oof_val_preds_lgb))
# Out:
# LightGBM OOF 검증 데이터 ROC-AUC : 0.7404072552729031

# %%
print('CatBoost OOF 검증 데이터 ROC-AUC :', roc_auc_score(y, oof_val_preds_catboost))
# Out:
# CatBoost OOF 검증 데이터 ROC-AUC : 0.7397209973764989

# %%
correlation = np.corrcoef(oof_val_preds_lgb, oof_val_preds_catboost)[0,1]
print(f"LightGBM과 CatBoost 예측값의 상관계수: {correlation}")
# Out:
# LightGBM과 CatBoost 예측값의 상관계수: 0.9943038122320139

# %%
# LightGBM과 XGBoost 앙상블 예측 (가중 평균)
ensemble_preds = oof_val_preds_lgb * 0.8 + oof_val_preds_catboost * 0.2  # LGB 60%, XGB 40%

# 앙상블한 예측값으로 ROC-AUC 확인
ensemble_roc_auc = roc_auc_score(y, ensemble_preds)
print(f"앙상블 OOF 검증 데이터 ROC-AUC: {ensemble_roc_auc}")
# Out:
# 앙상블 OOF 검증 데이터 ROC-AUC: 0.7404738612183165

# %%
# LightGBM과 XGBoost 앙상블 예측 (가중 평균)
ensemble_preds = oof_val_preds_lgb * 0.75 + oof_val_preds_catboost * 0.25  # LGB 60%, XGB 40%

# 앙상블한 예측값으로 ROC-AUC 확인
ensemble_roc_auc = roc_auc_score(y, ensemble_preds)
print(f"앙상블 OOF 검증 데이터 ROC-AUC: {ensemble_roc_auc}")
# Out:
# 앙상블 OOF 검증 데이터 ROC-AUC: 0.7404744164356338

# %%
ensemble_test_preds = oof_test_preds_lgb * 0.75 + oof_test_preds_catboost * 0.25
submission['probability'] = ensemble_test_preds
submission.to_csv('ensemble_lgbm_cat_submission.csv')

# %%
from scipy.optimize import minimize

# 최적의 가중치를 찾는 함수
def optimize_weights(weights):
    blended_preds = oof_val_preds_lgb * weights[0] + oof_val_preds_catboost * weights[1]
    return -roc_auc_score(y, blended_preds)  # 최대화 -> 최소화 문제로 변환

# 제약 조건 (가중치 합 1)
constraints = ({'type': 'eq', 'fun': lambda w: w[0] + w[1] - 1})

# 초기값 (LightGBM 60%, XGBoost 40%)
init_weights = [0.7, 0.3]

# 최적화 실행
best_weights = minimize(optimize_weights, init_weights, constraints=constraints, bounds=[(0, 1), (0, 1)])
print(f"최적 가중치: {best_weights.x}")
# Out:
# 최적 가중치: [0.6999979 0.3000021]

# %%
# LightGBM과 XGBoost 앙상블 예측 (가중 평균)
ensemble_preds = oof_val_preds_lgb * 0.6999979 + oof_val_preds_catboost * 0.3000021  # LGB 60%, XGB 40%

# 앙상블한 예측값으로 ROC-AUC 확인
ensemble_roc_auc = roc_auc_score(y, ensemble_preds)
print(f"앙상블 OOF 검증 데이터 ROC-AUC: {ensemble_roc_auc}")
# Out:
# 앙상블 OOF 검증 데이터 ROC-AUC: 0.7404686765162515
